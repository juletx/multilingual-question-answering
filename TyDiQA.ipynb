# %% [markdown]
# # Zero-Shot and Translation Experiments on TyDiQA

# %% [markdown]
# If you're opening this Notebook on colab, you will need to moun drive and change directory.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/master/Applications2/project
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/master/Applications2/project'
# /content

# %%
# %cd /content/drive/MyDrive/LAP/Subjects/AP2/project
# Out:
# /content/drive/MyDrive/LAP/Subjects/AP2/project

# %% [markdown]
# If you're opening this Notebook on colab, you will need to install 🤗 Transformers and 🤗 Datasets.

# %%
# !pip install datasets transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.2.2-py3-none-any.whl (346 kB)
#      |████████████████████████████████| 346 kB 35.4 MB/s
# Collecting transformers
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 58.1 MB/s
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.13)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 71.9 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.11.4)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 58.7 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 16.2 MB/s
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.6 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Collecting dill<0.3.5
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 7.6 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.7.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 63.6 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 72.9 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 64.8 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 76.9 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 18.5 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 4.1 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.12.2-py37-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 66.6 MB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: multidict, frozenlist, yarl, urllib3, asynctest, async-timeout, aiosignal, pyyaml, fsspec, dill, aiohttp, xxhash, tokenizers, responses, multiprocess, huggingface-hub, transformers, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.5.1
#     Uninstalling dill-0.3.5.1:
#       Successfully uninstalled dill-0.3.5.1
#   Attempting uninstall: multiprocess
#     Found existing installation: multiprocess 0.70.13
#     Uninstalling multiprocess-0.70.13:
#       Successfully uninstalled multiprocess-0.70.13
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 datasets-2.2.2 dill-0.3.4 frozenlist-1.3.0 fsspec-2022.5.0 huggingface-hub-0.7.0 multidict-6.0.2 multiprocess-0.70.12.2 pyyaml-6.0 responses-0.18.0 tokenizers-0.12.1 transformers-4.19.2 urllib3-1.25.11 xxhash-3.0.0 yarl-1.7.2

# %% [markdown]
# To be able to share your model with the community and generate results like the one shown in the picture below via the inference API, there are a few more steps to follow.
#
# First you have to store your authentication token from the Hugging Face website (sign up [here](https://huggingface.co/join) if you haven't already!) then execute the following cell and input your username and password:

# %%
from huggingface_hub import notebook_login

#notebook_login()

# %% [markdown]
# ## Create TyDiQA-XTREME Dataset

# %% [markdown]
# Make sure you are in the virtual environment where you installed Datasets, and run the following command:

# %%
# !huggingface-cli login

# %% [markdown]
# Login using your Hugging Face Hub credentials, and create a new dataset repository:

# %%
# !huggingface-cli repo create tydiqa_xtreme --type dataset

# %% [markdown]
# Install Git LFS and clone your repository:

# %%
# !git lfs install
# !git clone https://huggingface.co/datasets/juletxara/tydiqa_xtreme

# %% [markdown]
# We have to create these files to upload the dataset:
#
# * `README.md` is a Dataset card that describes the datasets contents,
# creation, and usage.
#
# * `tydiqa_xtreme.py` is your dataset loading script.
#
# * `dataset_infos.json` contains metadata about the dataset.

# %% [markdown]
# Run the following command to create the metadata file, `dataset_infos.json`. This will also test your new dataset loading script and make sure it works correctly.

# %%
# !datasets-cli test tydiqa_xtreme --save_infos --all_configs

# %% [markdown]
# If you want to be able to test your dataset script without downloading the full dataset, you need to create some dummy data for automated testing.

# %%
# !datasets-cli dummy_data tydiqa_xtreme --auto_generate --json_field data

# %% [markdown]
# ## Load TyDiQA-XTREME Dataset

# %%
from datasets import load_dataset, load_metric

langs = ["en", "ar", "bn", "fi", "id", "ko", "ru", "sw", "te"]
langs_translate_test = ["ar", "bn", "fi", "id", "ko", "ru", "sw", "te"]

tydiqa = {}
for lang in langs:
    tydiqa[lang] = load_dataset("juletxara/tydiqa_xtreme", lang)
# Out:
# Downloading builder script:   0%|          | 0.00/8.57k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/34.8k [00:00<?, ?B/s]
# Downloading and preparing dataset ty_di_qa/en (download: 3.52 MiB, generated: 2.82 MiB, post-processed: Unknown size, total: 6.35 MiB) to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/en/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/3.25M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/448k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/3696 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/440 [00:00<?, ? examples/s]
# Dataset ty_di_qa downloaded and prepared to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/en/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading and preparing dataset ty_di_qa/ar (download: 29.76 MiB, generated: 20.60 MiB, post-processed: Unknown size, total: 50.36 MiB) to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/ar/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e...
# Downloading data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/18.4M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.23M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/10.3M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.28M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/14805 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/921 [00:00<?, ? examples/s]
# Generating translate_train split:   0%|          | 0/3661 [00:00<?, ? examples/s]
# Generating translate_test split:   0%|          | 0/1594 [00:00<?, ? examples/s]
# Dataset ty_di_qa downloaded and prepared to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/ar/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e. Subsequent calls will reuse this data.
#   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading and preparing dataset ty_di_qa/bn (download: 16.98 MiB, generated: 10.65 MiB, post-processed: Unknown size, total: 27.63 MiB) to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/bn/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e...
# Downloading data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/4.98M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/254k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.4M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/154k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/2390 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/113 [00:00<?, ? examples/s]
# Generating translate_train split:   0%|          | 0/3585 [00:00<?, ? examples/s]
# Generating translate_test split:   0%|          | 0/181 [00:00<?, ? examples/s]
# Dataset ty_di_qa downloaded and prepared to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/bn/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e. Subsequent calls will reuse this data.
#   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading and preparing dataset ty_di_qa/fi (download: 9.96 MiB, generated: 7.85 MiB, post-processed: Unknown size, total: 17.81 MiB) to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/fi/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e...
# Downloading data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/5.33M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/744k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.45M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/921k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/6855 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/782 [00:00<?, ? examples/s]
# Generating translate_train split:   0%|          | 0/3670 [00:00<?, ? examples/s]
# Generating translate_test split:   0%|          | 0/1301 [00:00<?, ? examples/s]
# Dataset ty_di_qa downloaded and prepared to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/fi/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e. Subsequent calls will reuse this data.
#   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading and preparing dataset ty_di_qa/id (download: 8.73 MiB, generated: 7.16 MiB, post-processed: Unknown size, total: 15.89 MiB) to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/id/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e...
# Downloading data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/4.84M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/561k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.05M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/702k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/5702 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/565 [00:00<?, ? examples/s]
# Generating translate_train split:   0%|          | 0/3667 [00:00<?, ? examples/s]
# Generating translate_test split:   0%|          | 0/925 [00:00<?, ? examples/s]
# Dataset ty_di_qa downloaded and prepared to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/id/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e. Subsequent calls will reuse this data.
#   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading and preparing dataset ty_di_qa/ko (download: 5.59 MiB, generated: 3.12 MiB, post-processed: Unknown size, total: 8.71 MiB) to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/ko/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/284k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.27M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/302k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating test split:   0%|          | 0/276 [00:00<?, ? examples/s]
# Generating translate_train split:   0%|          | 0/3607 [00:00<?, ? examples/s]
# Generating translate_test split:   0%|          | 0/411 [00:00<?, ? examples/s]
# Dataset ty_di_qa downloaded and prepared to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/ko/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading and preparing dataset ty_di_qa/ru (download: 21.80 MiB, generated: 13.26 MiB, post-processed: Unknown size, total: 35.06 MiB) to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/ru/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e...
# Downloading data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/9.01M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.21M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.5M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.12M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/6490 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/812 [00:00<?, ? examples/s]
# Generating translate_train split:   0%|          | 0/3394 [00:00<?, ? examples/s]
# Generating translate_test split:   0%|          | 0/1437 [00:00<?, ? examples/s]
# Dataset ty_di_qa downloaded and prepared to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/ru/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e. Subsequent calls will reuse this data.
#   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading and preparing dataset ty_di_qa/sw (download: 5.20 MiB, generated: 4.16 MiB, post-processed: Unknown size, total: 9.36 MiB) to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/sw/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e...
# Downloading data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/338k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.03M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/405k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/2755 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/499 [00:00<?, ? examples/s]
# Generating translate_train split:   0%|          | 0/3622 [00:00<?, ? examples/s]
# Generating translate_test split:   0%|          | 0/820 [00:00<?, ? examples/s]
# Dataset ty_di_qa downloaded and prepared to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/sw/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e. Subsequent calls will reuse this data.
#   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading and preparing dataset ty_di_qa/te (download: 23.67 MiB, generated: 16.36 MiB, post-processed: Unknown size, total: 40.03 MiB) to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/te/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e...
# Downloading data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/10.1M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.17M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.7M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/829k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/5563 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/669 [00:00<?, ? examples/s]
# Generating translate_train split:   0%|          | 0/3658 [00:00<?, ? examples/s]
# Generating translate_test split:   0%|          | 0/1135 [00:00<?, ? examples/s]
# Dataset ty_di_qa downloaded and prepared to /root/.cache/huggingface/datasets/juletxara___ty_di_qa/te/1.1.0/1c2d9a4fbb2fabb701f77415ef0f5865ee320a9879108e17f65612a61b42c93e. Subsequent calls will reuse this data.
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
tydiqa
# Out:
# {'ar': DatasetDict({
#     train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 14805
#     })
#     test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 921
#     })
#     translate_train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 3661
#     })
#     translate_test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 1594
#     })
# }),
#  'bn': DatasetDict({
#     train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 2390
#     })
#     test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 113
#     })
#     translate_train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 3585
#     })
#     translate_test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 181
#     })
# }),
#  'en': DatasetDict({
#     train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 3696
#     })
#     test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 440
#     })
# }),
#  'fi': DatasetDict({
#     train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 6855
#     })
#     test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 782
#     })
#     translate_train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 3670
#     })
#     translate_test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 1301
#     })
# }),
#  'id': DatasetDict({
#     train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 5702
#     })
#     test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 565
#     })
#     translate_train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 3667
#     })
#     translate_test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 925
#     })
# }),
#  'ko': DatasetDict({
#     test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 276
#     })
#     translate_train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 3607
#     })
#     translate_test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 411
#     })
# }),
#  'ru': DatasetDict({
#     train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 6490
#     })
#     test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 812
#     })
#     translate_train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 3394
#     })
#     translate_test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 1437
#     })
# }),
#  'sw': DatasetDict({
#     train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 2755
#     })
#     test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 499
#     })
#     translate_train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 3622
#     })
#     translate_test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 820
#     })
# }),
#  'te': DatasetDict({
#     train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 5563
#     })
#     test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 669
#     })
#     translate_train: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 3658
#     })
#     translate_test: Dataset({
#         features: ['id', 'context', 'question', 'answers'],
#         num_rows: 1135
#     })
# })}

# %%
tydiqa["ar"]["train"][0]
# Out:
# {'answers': {'answer_start': [124],
#   'text': ['مسألة وجود العثمانيين المسلمين في أوروبا وطردهم منها واستعادة القسطنطينية من العثمانيين بعد سقوطها في 1453 وتهديد مصالح الدول الأوروبية في هذه المنطقة']},
#  'context': "المسألة الشرقية (بالإنجليزية: Eastern Question) (بالفرنسية: Question de l'orient): هي مسألة وجود العثمانيين المسلمين في أوروبا وطردهم منها واستعادة القسطنطينية من العثمانيين بعد سقوطها في 1453 وتهديد مصالح الدول الأوروبية في هذه المنطقة. كما يدل المصطلح على تصفية أملاك رجل أوروبا المريض في البلقان من طرف الدول الأوروبية.",
#  'id': '0',
#  'question': 'ما هي المسألة الشرقية ؟'}

# %%
tydiqa["ar"]["test"][0]
# Out:
# {'answers': {'answer_start': [657, 657], 'text': ['بطولتين', 'بطولتين']},
#  'context': 'أقيمت البطولة 21 مرة، شارك في النهائيات 78 دولة، وعدد الفرق التي فازت بالبطولة حتى الآن 8 فرق، ويعد المنتخب البرازيلي الأكثر تتويجاً بالكأس حيث فاز بها 5 مرات أعوام: 1958، 1962، 1970، 1994 و2002. يليه المنتخب الإيطالي الذي أحرزها 4 مرات في أعوام: 1934، 1938، 1982 و2006، بالمشاركة مع المنتخب الألماني الذي حققها 4 مرات أيضاً أعوام: 1954، 1974 و1990 و2014، ثم الأوروغواي والأرجنتين وفرنسا برصيد بطولتين. بينما أحرزت منتخبات إنجلترا وإسبانيا البطولة مرة واحدة.',
#  'id': '0',
#  'question': 'كم عدد مرات فوز الأوروغواي ببطولة كاس العالم لكرو القدم؟'}

# %%
tydiqa["ar"]["translate_train"][0]
# Out:
# {'answers': {'answer_start': [54], 'text': ['ليد زيبلين']},
#  'context': 'في عام 1968 ، تم تأسيس ثلاثة من أشهر رواد هذا النوع ، ليد زيبلين ، و Black Sabbath و Deep Purple. [6] على الرغم من أنهم جاءوا لجذب جماهير واسعة ، إلا أنهم كانوا غاضبين من النقاد. خلال منتصف سبعينيات القرن الماضي ، ساعد جوداس بريست في تحفيز تطور هذا النوع من خلال التخلص من الكثير من تأثير البلوز ، [7] [8] قدم موتورهيد حساسية صخرية فاسقة وتأكيد متزايد على السرعة. ابتداءً من أواخر سبعينيات القرن العشرين ، اتبعت الفرق في الموجة الجديدة من المعدن البريطاني الثقيل مثل Iron Maiden و Saxon مسارًا مشابهًا. قبل نهاية العقد ، أصبحت مراوح المعادن الثقيلة تُعرف باسم "رؤوس المعادن" أو "headbangers".',
#  'id': '0',
#  'question': 'من كان أول فرقة معدنية ثقيلة؟'}

# %%
tydiqa["ar"]["translate_test"][0]
# Out:
# {'answers': {'answer_start': [95], 'text': ['120 A.H.']},
#  'context': 'The origins of the Hanafi school go back to the early second century AH, specifically the year 120 A.H., on the day that Abu Hanifa sat on the chair of Fatwa and teaching behind his Sheikh Hammad bin Abi Suleiman, and this year was a witness to the emergence of the first certified jurisprudence school. [3] Through this fiqh school, which was headed by Imam Abu Hanifa himself, the Hanafi school began to expand and spread, as it became for him pupils and companions accompanying his ring, writing down his opinions and disseminating them, so they - especially the two companions Abu Yusef and Muhammad bin Al-Hassan Al-Shaibani - played a major role in the rise of the doctrine, And the spread of his opinions and sayings. [4] Ibn Abd al-Barr says: “Abu Hanifa had great companions, rulers of the world, whose jurisprudence appeared on their hands, the eldest of whom was Abu Yusuf Yaqoub bin Ibrahim Al-Ansari.” [5] Ibn Hajar al-Haytami said: “And Rizk - meaning Abu Hanifa - ample luck in his followers, so they liberated the origins of his doctrine and branches, and they carefully considered its movables and its reasoning, until it became - by the grace of God - the ruler of the rules, the mineral of benefits.” [6]',
#  'id': '0',
#  'question': 'When was the Al-Khanfy school established in Islam?'}

# %% [markdown]
# ## Load SQuAD Dataset
#
# Stanford Question Answering Dataset (SQuAD) is a reading comprehension dataset, consisting of questions posed by crowdworkers on a set of Wikipedia articles, where the answer to every question is a segment of text, or span, from the corresponding reading passage, or the question might be unanswerable. https://arxiv.org/pdf/1606.05250.pdf

# %%
from datasets import load_dataset, load_metric

# %%
squad = load_dataset("squad")
# Out:
# Reusing dataset squad (/root/.cache/huggingface/datasets/squad/plain_text/1.0.0/d6ec3ceb99ca480ce37cdd35555d6cb2511d223b9150cce08a837ef62ffea453)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
squad
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 87599
#     })
#     validation: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 10570
#     })
# })

# %%
squad["train"][0]
# Out:
# {'answers': {'answer_start': [515], 'text': ['Saint Bernadette Soubirous']},
#  'context': 'Architecturally, the school has a Catholic character. Atop the Main Building\'s gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.',
#  'id': '5733be284776f41900661182',
#  'question': 'To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?',
#  'title': 'University_of_Notre_Dame'}

# %%
squad["validation"][0]
# Out:
# {'answers': {'answer_start': [177, 177, 177],
#   'text': ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']},
#  'context': 'Super Bowl 50 was an American football game to determine the champion of the National Football League (NFL) for the 2015 season. The American Football Conference (AFC) champion Denver Broncos defeated the National Football Conference (NFC) champion Carolina Panthers 24–10 to earn their third Super Bowl title. The game was played on February 7, 2016, at Levi\'s Stadium in the San Francisco Bay Area at Santa Clara, California. As this was the 50th Super Bowl, the league emphasized the "golden anniversary" with various gold-themed initiatives, as well as temporarily suspending the tradition of naming each Super Bowl game with Roman numerals (under which the game would have been known as "Super Bowl L"), so that the logo could prominently feature the Arabic numerals 50.',
#  'id': '56be4db0acb8001400a502ec',
#  'question': 'Which NFL team represented the AFC at Super Bowl 50?',
#  'title': 'Super_Bowl_50'}

# %% [markdown]
# ## Preprocessing SQuAD
#
# Load the mBERT tokenizer to process the question and context fields.

# %%
from transformers import AutoTokenizer

model_name = "bert-base-multilingual-cased"

tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/972k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.87M [00:00<?, ?B/s]

# %% [markdown]
# Now one specific thing for the preprocessing in question answering is how to deal with very long documents. We usually truncate them in other tasks, when they are longer than the model maximum sentence length, but here, removing part of the the context might result in losing the answer we are looking for. To deal with this, we will allow one (long) example in our dataset to give several input features, each of length shorter than the maximum length of the model (or the one we set as a hyper-parameter). Also, just in case the answer lies at the point we split a long context, we allow some overlap between the features we generate controlled by the hyper-parameter `doc_stride`:

# %%
max_length = 384 # The maximum length of a feature (question and context)
doc_stride = 128 # The authorized overlap between two part of the context when splitting it is needed.

# %% [markdown]
# There are a few preprocessing steps particular to question answering that we should be aware of:
#
# 1. Some examples in a dataset may have a very long context that exceeds the maximum input length of the model. Truncate only the context by setting `truncation="only_second"`.
# 2. Next, map the start and end positions of the answer to the original context by setting `return_offset_mapping=True`.
# 3. With the mapping in hand, you can find the start and end tokens of the answer. Use the `sequence_ids` method to find which part of the offset corresponds to the question and which corresponds to the `context`.

# %%
def prepare_train_features(examples):
    # Some of the questions have lots of whitespace on the left, which is not useful and will make the
    # truncation of the context fail (the tokenized question will take a lots of space). So we remove that
    # left whitespace
    examples["question"] = [q.lstrip() for q in examples["question"]]

    # Tokenize our examples with truncation and padding, but keep the overflows using a stride. This results
    # in one example possible giving several features when a context is long, each of those features having a
    # context that overlaps a bit the context of the previous feature.
    tokenized_examples = tokenizer(
        examples["question"],
        examples["context"],
        truncation="only_second",
        max_length=max_length,
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    # Since one example might give us several features if it has a long context, we need a map from a feature to
    # its corresponding example. This key gives us just that.
    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")
    # The offset mappings will give us a map from token to character position in the original context. This will
    # help us compute the start_positions and end_positions.
    offset_mapping = tokenized_examples.pop("offset_mapping")

    # Let's label those examples!
    tokenized_examples["start_positions"] = []
    tokenized_examples["end_positions"] = []

    for i, offsets in enumerate(offset_mapping):
        # We will label impossible answers with the index of the CLS token.
        input_ids = tokenized_examples["input_ids"][i]
        cls_index = input_ids.index(tokenizer.cls_token_id)

        # Grab the sequence corresponding to that example (to know what is the context and what is the question).
        sequence_ids = tokenized_examples.sequence_ids(i)

        # One example can give several spans, this is the index of the example containing this span of text.
        sample_index = sample_mapping[i]
        answers = examples["answers"][sample_index]
        # If no answers are given, set the cls_index as answer.
        if len(answers["answer_start"]) == 0:
            tokenized_examples["start_positions"].append(cls_index)
            tokenized_examples["end_positions"].append(cls_index)
        else:
            # Start/end character index of the answer in the text.
            start_char = answers["answer_start"][0]
            end_char = start_char + len(answers["text"][0])

            # Start token index of the current span in the text.
            token_start_index = 0
            while sequence_ids[token_start_index] != 1:
                token_start_index += 1

            # End token index of the current span in the text.
            token_end_index = len(input_ids) - 1
            while sequence_ids[token_end_index] != 1:
                token_end_index -= 1

            # Detect if the answer is out of the span (in which case this feature is labeled with the CLS index).
            if not (offsets[token_start_index][0] <= start_char and offsets[token_end_index][1] >= end_char):
                tokenized_examples["start_positions"].append(cls_index)
                tokenized_examples["end_positions"].append(cls_index)
            else:
                # Otherwise move the token_start_index and token_end_index to the two ends of the answer.
                # Note: we could go after the last offset if the answer is the last word (edge case).
                while token_start_index < len(offsets) and offsets[token_start_index][0] <= start_char:
                    token_start_index += 1
                tokenized_examples["start_positions"].append(token_start_index - 1)
                while offsets[token_end_index][1] >= end_char:
                    token_end_index -= 1
                tokenized_examples["end_positions"].append(token_end_index + 1)

    return tokenized_examples

# %% [markdown]
# Use 🤗 Datasets map function to apply the preprocessing function over the entire dataset. You can speed up the map function by setting `batched=True` to process multiple elements of the dataset at once. Remove the columns you don’t need.

# %%
squad_train = squad.map(prepare_train_features, batched=True, 
                            remove_columns=squad["train"].column_names)
# Out:
#   0%|          | 0/88 [00:00<?, ?ba/s]
#   0%|          | 0/11 [00:00<?, ?ba/s]

# %% [markdown]
# The evaluation features are similar to the train features. We have to check a given span is inside the context (and not the question) and how to get back the text inside. To do this, we need to add two things to our validation features:
# - the ID of the example that generated the feature (since each example can generate several features, as seen before);
# - the offset mapping that will give us a map from token indices to character positions in the context.
#
# That's why we will re-process the validation set with the following function, slightly different from `prepare_train_features`:

# %%
def prepare_validation_features(examples):
    # Some of the questions have lots of whitespace on the left, which is not useful and will make the
    # truncation of the context fail (the tokenized question will take a lots of space). So we remove that
    # left whitespace
    examples["question"] = [q.lstrip() for q in examples["question"]]

    # Tokenize our examples with truncation and maybe padding, but keep the overflows using a stride. This results
    # in one example possible giving several features when a context is long, each of those features having a
    # context that overlaps a bit the context of the previous feature.
    tokenized_examples = tokenizer(
        examples["question"],
        examples["context"],
        truncation="only_second",
        max_length=max_length,
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    # Since one example might give us several features if it has a long context, we need a map from a feature to
    # its corresponding example. This key gives us just that.
    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")

    # We keep the example_id that gave us this feature and we will store the offset mappings.
    tokenized_examples["example_id"] = []

    for i in range(len(tokenized_examples["input_ids"])):
        # Grab the sequence corresponding to that example (to know what is the context and what is the question).
        sequence_ids = tokenized_examples.sequence_ids(i)
        context_index = 1
        
        # One example can give several spans, this is the index of the example containing this span of text.
        sample_index = sample_mapping[i]
        tokenized_examples["example_id"].append(examples["id"][sample_index])

        # Set to None the offset_mapping that are not part of the context so it's easy to determine if a token
        # position is part of the context or not.
        tokenized_examples["offset_mapping"][i] = [
            (o if sequence_ids[k] == context_index else None)
            for k, o in enumerate(tokenized_examples["offset_mapping"][i])
        ]

    return tokenized_examples

# %% [markdown]
# Use the map function again to apply the preprocessing function over the validation dataset. You can speed up the map function by setting `batched=True` to process multiple elements of the dataset at once. Remove the columns you don’t need.

# %%
squad_eval = squad["validation"].map(prepare_validation_features, batched=True, 
                                          remove_columns=squad["validation"].column_names)
# Out:
#   0%|          | 0/11 [00:00<?, ?ba/s]

# %% [markdown]
# ## Fine-tuning mBERT

# %% [markdown]
# Now that our data is ready for training, we can download the pretrained model and fine-tune it. Since our task is question answering, we use the `AutoModelForQuestionAnswering` class. Like with the tokenizer, the `from_pretrained` method will download and cache the model for us:

# %%
from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer

model_name = "bert-base-multilingual-cased"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/681M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForQuestionAnswering: ['cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# Then we will need a data collator that will batch our processed examples together, here the default one will work:

# %%
from transformers import DefaultDataCollator

data_collator = DefaultDataCollator()

# %% [markdown]
# To instantiate a `Trainer`, we will need to define three more things. The most important is the [`TrainingArguments`](https://huggingface.co/transformers/main_classes/trainer.html#transformers.TrainingArguments), which is a class that contains all the attributes to customize the training. It requires one folder name, which will be used to save the checkpoints of the model, and all other arguments are optional:

# %%
batch_size = 16
args = TrainingArguments(
    "bert-base-multilingual-cased-squad",
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
    push_to_hub=True,
)

# %% [markdown]
# We will evaluate our model and compute metrics in the next section (this is a very long operation, so we will only compute the evaluation loss during training).
#
# Then we just need to pass all of this along with our datasets to the `Trainer`:

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=squad_train["train"],
    eval_dataset=squad_train["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
)

# %% [markdown]
# We can now finetune our model by just calling the `train` method:

# %%
# trainer.train()

# %%
trainer.push_to_hub()

# %% [markdown]
# ## Evaluating mBERT
#
# We load a model that is already finetuned on SQuAD to save time. We evaluate on the validation set of SQuAD.

# %%
from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer

model_name = "salti/bert-base-multilingual-cased-finetuned-squad"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="bert-base-multilingual-cased-finetuned-squad",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpx7vo12og
# Downloading:   0%|          | 0.00/822 [00:00<?, ?B/s]
# storing https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/1df6572a9ae2fd1152d4fa4e3b9d30e0d303c69cb87d5b8401ef5cb032016bef.aa91fcc51e661ddbf70fda4906759b1d8178a512385633adf5d0db934ae1e333
# creating metadata file for /root/.cache/huggingface/transformers/1df6572a9ae2fd1152d4fa4e3b9d30e0d303c69cb87d5b8401ef5cb032016bef.aa91fcc51e661ddbf70fda4906759b1d8178a512385633adf5d0db934ae1e333
# loading configuration file https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/1df6572a9ae2fd1152d4fa4e3b9d30e0d303c69cb87d5b8401ef5cb032016bef.aa91fcc51e661ddbf70fda4906759b1d8178a512385633adf5d0db934ae1e333
# Model config BertConfig {
#   "_name_or_path": "salti/bert-base-multilingual-cased-finetuned-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 119547
# }
#
# https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpnb8b0c2o
# Downloading:   0%|          | 0.00/676M [00:00<?, ?B/s]
# storing https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/9f54849aca742a855728dc8a74c1a733627678a2e8c7a97ba60e2b318ad1438a.b9c031b09975cb84030a5da7731e0b35844cbf7eed5f7ddc0dc0704ba6cc5802
# creating metadata file for /root/.cache/huggingface/transformers/9f54849aca742a855728dc8a74c1a733627678a2e8c7a97ba60e2b318ad1438a.b9c031b09975cb84030a5da7731e0b35844cbf7eed5f7ddc0dc0704ba6cc5802
# loading weights file https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/9f54849aca742a855728dc8a74c1a733627678a2e8c7a97ba60e2b318ad1438a.b9c031b09975cb84030a5da7731e0b35844cbf7eed5f7ddc0dc0704ba6cc5802
# All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# All the weights of BertForQuestionAnswering were initialized from the model checkpoint at salti/bert-base-multilingual-cased-finetuned-squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %% [markdown]
# We can grab the predictions for all features by using the `Trainer.predict` method:

# %%
raw_predictions = trainer.predict(squad_eval)
# Out:
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 10851
#   Batch size = 16
#     <div>
#
#       <progress value='679' max='679' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [679/679 04:39]
#     </div>

# %% [markdown]
# The `Trainer` *hides* the columns that are not used by the model (here `example_id` and `offset_mapping` which we will need for our post-processing), so we set them back:

# %%
squad_eval.set_format(type=squad_eval.format["type"], 
                      columns=list(squad_eval.features.keys()))

# %% [markdown]
# We can now refine the test we had before: since we set `None` in the offset mappings when it corresponds to a part of the question, it's easy to check if an answer is fully inside the context. We also eliminate very long answers from our considerations (with an hyper-parameter we can tune)
#
# As we mentioned in the code above, this was easy on the first feature because we knew it comes from the first example. For the other features, we will need a map between examples and their corresponding features. Also, since one example can give several features, we will need to gather together all the answers in all the features generated by a given example, then pick the best one. The following code builds a map from example index to its corresponding features indices.

# %%
from tqdm.auto import tqdm
import collections
import numpy as np

def postprocess_qa_predictions(examples, features, raw_predictions, n_best_size = 20, max_answer_length = 30):
    all_start_logits, all_end_logits = raw_predictions
    # Build a map example to its corresponding features.
    example_id_to_index = {k: i for i, k in enumerate(examples["id"])}
    features_per_example = collections.defaultdict(list)
    for i, feature in enumerate(features):
        features_per_example[example_id_to_index[feature["example_id"]]].append(i)

    # The dictionaries we have to fill.
    predictions = collections.OrderedDict()

    # Logging.
    print(f"Post-processing {len(examples)} example predictions split into {len(features)} features.")

    # Let's loop over all the examples!
    for example_index, example in enumerate(tqdm(examples)):
        # Those are the indices of the features associated to the current example.
        feature_indices = features_per_example[example_index]

        valid_answers = []
        
        context = example["context"]
        # Looping through all the features associated to the current example.
        for feature_index in feature_indices:
            # We grab the predictions of the model for this feature.
            start_logits = all_start_logits[feature_index]
            end_logits = all_end_logits[feature_index]
            # This is what will allow us to map some the positions in our logits to span of texts in the original
            # context.
            offset_mapping = features[feature_index]["offset_mapping"]

            # Go through all possibilities for the `n_best_size` greater start and end logits.
            start_indexes = np.argsort(start_logits)[-1 : -n_best_size - 1 : -1].tolist()
            end_indexes = np.argsort(end_logits)[-1 : -n_best_size - 1 : -1].tolist()
            for start_index in start_indexes:
                for end_index in end_indexes:
                    # Don't consider out-of-scope answers, either because the indices are out of bounds or correspond
                    # to part of the input_ids that are not in the context.
                    if (
                        start_index >= len(offset_mapping)
                        or end_index >= len(offset_mapping)
                        or offset_mapping[start_index] is None
                        or offset_mapping[end_index] is None
                    ):
                        continue
                    # Don't consider answers with a length that is either < 0 or > max_answer_length.
                    if end_index < start_index or end_index - start_index + 1 > max_answer_length:
                        continue

                    start_char = offset_mapping[start_index][0]
                    end_char = offset_mapping[end_index][1]
                    valid_answers.append(
                        {
                            "score": start_logits[start_index] + end_logits[end_index],
                            "text": context[start_char: end_char]
                        }
                    )
        
        if len(valid_answers) > 0:
            best_answer = sorted(valid_answers, key=lambda x: x["score"], reverse=True)[0]
        else:
            # In the very rare edge case we have not a single non-null prediction, we create a fake prediction to avoid
            # failure.
            best_answer = {"text": "", "score": 0.0}
        
        # Let's pick our final answer: the best one
        predictions[example["id"]] = best_answer["text"]

    return predictions

# %% [markdown]
# And we can apply our post-processing function to our raw predictions:

# %%
final_predictions = postprocess_qa_predictions(squad["validation"], squad_eval, raw_predictions.predictions)
# Out:
# Post-processing 10570 example predictions split into 10851 features.
#   0%|          | 0/10570 [00:00<?, ?it/s]

# %% [markdown]
# Then we can load the metric from the datasets library.

# %%
metric = load_metric("squad")
# Out:
# Downloading builder script:   0%|          | 0.00/1.72k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.12k [00:00<?, ?B/s]

# %% [markdown]
# Then we can call compute on it. We just need to format predictions and labels a bit as it expects a list of dictionaries and not one big dictionary.

# %%
formatted_predictions = [{"id": k, "prediction_text": v} for k, v in final_predictions.items()]
references = [{"id": ex["id"], "answers": ex["answers"]} for ex in squad["validation"]]
metric.compute(predictions=formatted_predictions, references=references)
# Out:
# {'exact_match': 81.90160832544939, 'f1': 89.121876471452}

# %% [markdown]
# ## Zero-Shot mBERT
#
# Zero-Shot performance of the mBERT model fine-tuned on SQuAD.

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "salti/bert-base-multilingual-cased-finetuned-squad"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="bert-base-multilingual-cased-finetuned-squad",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# Downloading:   0%|          | 0.00/822 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/676M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/264 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/972k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %% [markdown]
# Use the map function again to apply the preprocessing function over the validation dataset. You can speed up the map function by setting `batched=True` to process multiple elements of the dataset at once. Remove the columns you don’t need.

# %%
from collections import defaultdict

tydiqa_prep = defaultdict(dict)

def map_datasets(langs, split, prepare_features):
    for lang in langs:
        tydiqa_prep[lang][split] = tydiqa[lang][split].map(prepare_features, batched=True, 
                                    remove_columns=tydiqa[lang][split].column_names)

# %%
split = "test"
map_datasets(langs, split, prepare_validation_features)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
def compute_results(langs, split):
    results = {}
    for lang in langs:
        # We can grab the predictions for all features by using the method
        raw_predictions = trainer.predict(tydiqa_prep[lang][split])

        # example_id and offset_mapping which we will need for our post-processing
        tydiqa_prep[lang][split].set_format(type=tydiqa_prep[lang][split].format["type"], 
                        columns=list(tydiqa_prep[lang][split].features.keys()))
        
        # And we can apply our post-processing function to our raw predictions
        final_predictions = postprocess_qa_predictions(tydiqa[lang][split], tydiqa_prep[lang][split], raw_predictions.predictions)

        # We just need to format predictions and labels a bit as it expects a list of dictionaries and not one big dictionary.
        formatted_predictions = [{"id": k, "prediction_text": v} for k, v in final_predictions.items()]
        references = [{"id": ex["id"], "answers": ex["answers"]} for ex in tydiqa[lang][split]]
        results[lang] = metric.compute(predictions=formatted_predictions, references=references)
    return results

# %%
results_zero_shot_mbert = compute_results(langs, split)
print(results_zero_shot_mbert)
# Out:
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 447
#   Batch size = 16
#     <div>
#
#       <progress value='344' max='28' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [28/28 02:24]
#     </div>
# Post-processing 440 example predictions split into 447 features.
#   0%|          | 0/440 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 998
#   Batch size = 16
# Post-processing 921 example predictions split into 998 features.
#   0%|          | 0/921 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 140
#   Batch size = 16
# Post-processing 113 example predictions split into 140 features.
#   0%|          | 0/113 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 810
#   Batch size = 16
# Post-processing 782 example predictions split into 810 features.
#   0%|          | 0/782 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 580
#   Batch size = 16
# Post-processing 565 example predictions split into 580 features.
#   0%|          | 0/565 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 298
#   Batch size = 16
# Post-processing 276 example predictions split into 298 features.
#   0%|          | 0/276 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 884
#   Batch size = 16
# Post-processing 812 example predictions split into 884 features.
#   0%|          | 0/812 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 503
#   Batch size = 16
# Post-processing 499 example predictions split into 503 features.
#   0%|          | 0/499 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 776
#   Batch size = 16
# Post-processing 669 example predictions split into 776 features.
#   0%|          | 0/669 [00:00<?, ?it/s]
# {'en': {'exact_match': 69.77272727272727, 'f1': 77.84015311769087}, 'ar': {'exact_match': 45.05971769815418, 'f1': 60.57742187303621}, 'bn': {'exact_match': 47.78761061946903, 'f1': 59.49304382932701}, 'fi': {'exact_match': 50.12787723785166, 'f1': 60.569522528041404}, 'id': {'exact_match': 50.61946902654867, 'f1': 62.975492945116876}, 'ko': {'exact_match': 39.492753623188406, 'f1': 47.93306042066532}, 'ru': {'exact_match': 47.29064039408867, 'f1': 65.29395605159924}, 'sw': {'exact_match': 49.498997995991985, 'f1': 60.98986411639031}, 'te': {'exact_match': 41.4050822122571, 'f1': 48.89727346165936}}

# %%
import pandas as pd
def results_df(results_dict, model):
    F1colname = "F1_" + model
    EMcolname = "EM_" + model
    dict_results = defaultdict(list)
    for lang, scores in results_dict.items():
        dict_results["lang"].append(lang)
        dict_results[F1colname].append(scores['f1'])
        dict_results[EMcolname].append(scores['exact_match'])

    avg_f1 = np.average(dict_results[F1colname])
    avg_em = np.average(dict_results[EMcolname])
    dict_results["lang"].append('avg')
    dict_results[F1colname].append(avg_f1)
    dict_results[EMcolname].append(avg_em)
    df_results = pd.DataFrame(dict_results).round(2)
    return df_results

# %%
df_results_zero_shot_mbert = results_df(results_zero_shot_mbert, "Zero-shot mBERT")
df_results_zero_shot_mbert.to_csv("results/tydiqa/results_zero_shot_mbert.csv")
df_results_zero_shot_mbert
# Out:
#   lang  F1_Zero-shot mBERT  EM_Zero-shot mBERT
# 0   en               77.84               69.77
# 1   ar               60.58               45.06
# 2   bn               59.49               47.79
# 3   fi               60.57               50.13
# 4   id               62.98               50.62
# 5   ko               47.93               39.49
# 6   ru               65.29               47.29
# 7   sw               60.99               49.50
# 8   te               48.90               41.41
# 9  avg               60.51               49.01

# %% [markdown]
# ## Zero-Shot XLM-R
#
# Zero-Shot performance of the XLM-R model fine-tuned on SQuAD.

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "vanichandna/xlm-roberta-finetuned-squad"
model = AutoModelForQuestionAnswering.from_pretrained(model_name,from_tf=True)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="xlm-roberta-finetuned-squad",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpu5467te_
# Downloading:   0%|          | 0.00/688 [00:00<?, ?B/s]
# storing https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/6e9fab04c4168068e4162152496d68d0594b8a838953657e9234b70b2c4932fb.b04b4828cf6cfcbbcba34b7e4fc29fe9a0563001f3cedda0f9cf6487875eae92
# creating metadata file for /root/.cache/huggingface/transformers/6e9fab04c4168068e4162152496d68d0594b8a838953657e9234b70b2c4932fb.b04b4828cf6cfcbbcba34b7e4fc29fe9a0563001f3cedda0f9cf6487875eae92
# loading configuration file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/6e9fab04c4168068e4162152496d68d0594b8a838953657e9234b70b2c4932fb.b04b4828cf6cfcbbcba34b7e4fc29fe9a0563001f3cedda0f9cf6487875eae92
# Model config XLMRobertaConfig {
#   "_name_or_path": "vanichandna/xlm-roberta-finetuned-squad",
#   "architectures": [
#     "XLMRobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/tf_model.h5 not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpnfssg5gu
# Downloading:   0%|          | 0.00/1.03G [00:00<?, ?B/s]
# storing https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/tf_model.h5 in cache at /root/.cache/huggingface/transformers/40231dec3bc81ec27bf1027247098bd684738dffa5f2296b2cad573879d0c229.fdcf91f65f36389325caf97398f95d17232f926dca8f8ecac72019c5ca36ba9d.h5
# creating metadata file for /root/.cache/huggingface/transformers/40231dec3bc81ec27bf1027247098bd684738dffa5f2296b2cad573879d0c229.fdcf91f65f36389325caf97398f95d17232f926dca8f8ecac72019c5ca36ba9d.h5
# loading weights file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/tf_model.h5 from cache at /root/.cache/huggingface/transformers/40231dec3bc81ec27bf1027247098bd684738dffa5f2296b2cad573879d0c229.fdcf91f65f36389325caf97398f95d17232f926dca8f8ecac72019c5ca36ba9d.h5
# Loading TensorFlow weights from /root/.cache/huggingface/transformers/40231dec3bc81ec27bf1027247098bd684738dffa5f2296b2cad573879d0c229.fdcf91f65f36389325caf97398f95d17232f926dca8f8ecac72019c5ca36ba9d.h5
# All TF 2.0 model weights were used when initializing XLMRobertaForQuestionAnswering.
#
# All the weights of XLMRobertaForQuestionAnswering were initialized from the TF 2.0 model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use XLMRobertaForQuestionAnswering for predictions without further training.
# Weights or buffers not loaded from TF 2.0 model: set()
# https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpjmfyzts3
# Downloading:   0%|          | 0.00/398 [00:00<?, ?B/s]
# storing https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/14a0caad62ab9246eaaf3d48369dcfa9230e8c7a75c21a5a5b984e9b681a780b.b36482fbec4a714d3cfec99e0b05f4fdeec9e759090a78aed5597583a8b4783d
# creating metadata file for /root/.cache/huggingface/transformers/14a0caad62ab9246eaaf3d48369dcfa9230e8c7a75c21a5a5b984e9b681a780b.b36482fbec4a714d3cfec99e0b05f4fdeec9e759090a78aed5597583a8b4783d
# https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpvp0crcfd
# Downloading:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# storing https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/tokenizer.json in cache at /root/.cache/huggingface/transformers/7f7f92d02ee98c92db3e0ef5445a40b8301c4206d4df0adc2bbb55b109b17dc3.d9915425c8f75472760a4bb40b4d5d0b3ab357a1b00aaf7917cda68403cbc936
# creating metadata file for /root/.cache/huggingface/transformers/7f7f92d02ee98c92db3e0ef5445a40b8301c4206d4df0adc2bbb55b109b17dc3.d9915425c8f75472760a4bb40b4d5d0b3ab357a1b00aaf7917cda68403cbc936
# https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpvek31oi5
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# storing https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/special_tokens_map.json in cache at /root/.cache/huggingface/transformers/21e94506b48b2fcd8bf2ffb7d2216e68cb34dd50b493e0cdbffbb6c97efd961b.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# creating metadata file for /root/.cache/huggingface/transformers/21e94506b48b2fcd8bf2ffb7d2216e68cb34dd50b493e0cdbffbb6c97efd961b.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# loading file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/sentencepiece.bpe.model from cache at None
# loading file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/7f7f92d02ee98c92db3e0ef5445a40b8301c4206d4df0adc2bbb55b109b17dc3.d9915425c8f75472760a4bb40b4d5d0b3ab357a1b00aaf7917cda68403cbc936
# loading file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/21e94506b48b2fcd8bf2ffb7d2216e68cb34dd50b493e0cdbffbb6c97efd961b.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# loading file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/14a0caad62ab9246eaaf3d48369dcfa9230e8c7a75c21a5a5b984e9b681a780b.b36482fbec4a714d3cfec99e0b05f4fdeec9e759090a78aed5597583a8b4783d
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
split = "test"
map_datasets(langs, split, prepare_validation_features)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
results_zero_shot_xlm_r = compute_results(langs, split)
print(results_zero_shot_xlm_r)
# Out:
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 448
#   Batch size = 16
#     <div>
#
#       <progress value='335' max='28' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [28/28 02:12]
#     </div>
# Post-processing 440 example predictions split into 448 features.
#   0%|          | 0/440 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 968
#   Batch size = 16
# Post-processing 921 example predictions split into 968 features.
#   0%|          | 0/921 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 127
#   Batch size = 16
# Post-processing 113 example predictions split into 127 features.
#   0%|          | 0/113 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 802
#   Batch size = 16
# Post-processing 782 example predictions split into 802 features.
#   0%|          | 0/782 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 577
#   Batch size = 16
# Post-processing 565 example predictions split into 577 features.
#   0%|          | 0/565 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 294
#   Batch size = 16
# Post-processing 276 example predictions split into 294 features.
#   0%|          | 0/276 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 862
#   Batch size = 16
# Post-processing 812 example predictions split into 862 features.
#   0%|          | 0/812 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 501
#   Batch size = 16
# Post-processing 499 example predictions split into 501 features.
#   0%|          | 0/499 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 715
#   Batch size = 16
# Post-processing 669 example predictions split into 715 features.
#   0%|          | 0/669 [00:00<?, ?it/s]
# {'en': {'exact_match': 65.9090909090909, 'f1': 75.1890783516253}, 'ar': {'exact_match': 52.76872964169381, 'f1': 66.7375641026191}, 'bn': {'exact_match': 51.32743362831859, 'f1': 67.46561697889129}, 'fi': {'exact_match': 62.27621483375959, 'f1': 72.62019667711722}, 'id': {'exact_match': 61.5929203539823, 'f1': 75.77416390690544}, 'ko': {'exact_match': 53.6231884057971, 'f1': 62.614060399540314}, 'ru': {'exact_match': 48.891625615763544, 'f1': 67.5483819869013}, 'sw': {'exact_match': 59.11823647294589, 'f1': 68.83363807670953}, 'te': {'exact_match': 58.5949177877429, 'f1': 74.5533002905728}}

# %%
df_results_zero_shot_xlm_r = results_df(results_zero_shot_xlm_r, "Zero-shot XLM-R")
df_results_zero_shot_xlm_r.to_csv("results/tydiqa/results_zero_shot_xlm_r.csv")
df_results_zero_shot_xlm_r
# Out:
#   lang  F1_Zero-shot XLM-R  EM_Zero-shot XLM-R
# 0   en               75.19               65.91
# 1   ar               66.74               52.77
# 2   bn               67.47               51.33
# 3   fi               72.62               62.28
# 4   id               75.77               61.59
# 5   ko               62.61               53.62
# 6   ru               67.55               48.89
# 7   sw               68.83               59.12
# 8   te               74.55               58.59
# 9  avg               70.15               57.12

# %% [markdown]
# ## Zero-Shot XLM-R-large
#
# Zero-Shot performance of the XLM-R-large model fine-tuned on SQuAD.

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "Palak/xlm-roberta-large_squad"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="xlm-roberta-large_squad",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpkhtfp2qz
# Downloading:   0%|          | 0.00/718 [00:00<?, ?B/s]
# storing https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/15ba31e9d5d227c3e7514429b9e154b4dd9fa20dc6634e2aa859a6570580ab8a.e0ee6561aeb1e6c81ca8555d0aed71ddc7b312c694416a29b2dd0b16df13a0b3
# creating metadata file for /root/.cache/huggingface/transformers/15ba31e9d5d227c3e7514429b9e154b4dd9fa20dc6634e2aa859a6570580ab8a.e0ee6561aeb1e6c81ca8555d0aed71ddc7b312c694416a29b2dd0b16df13a0b3
# loading configuration file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/15ba31e9d5d227c3e7514429b9e154b4dd9fa20dc6634e2aa859a6570580ab8a.e0ee6561aeb1e6c81ca8555d0aed71ddc7b312c694416a29b2dd0b16df13a0b3
# Model config XLMRobertaConfig {
#   "_name_or_path": "Palak/xlm-roberta-large_squad",
#   "architectures": [
#     "XLMRobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpmfkawvrw
# Downloading:   0%|          | 0.00/2.08G [00:00<?, ?B/s]
# storing https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/8edefbae0f1cc20d5925e7aeb8dd97881317810b29b16f0b519cabf0cd976fcb.7a0fe9d2258fd179f0fd3372c78a7daa343f8f5fcacba19a70f8f4bfcfa6a3a6
# creating metadata file for /root/.cache/huggingface/transformers/8edefbae0f1cc20d5925e7aeb8dd97881317810b29b16f0b519cabf0cd976fcb.7a0fe9d2258fd179f0fd3372c78a7daa343f8f5fcacba19a70f8f4bfcfa6a3a6
# loading weights file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/8edefbae0f1cc20d5925e7aeb8dd97881317810b29b16f0b519cabf0cd976fcb.7a0fe9d2258fd179f0fd3372c78a7daa343f8f5fcacba19a70f8f4bfcfa6a3a6
# All model checkpoint weights were used when initializing XLMRobertaForQuestionAnswering.
#
# All the weights of XLMRobertaForQuestionAnswering were initialized from the model checkpoint at Palak/xlm-roberta-large_squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use XLMRobertaForQuestionAnswering for predictions without further training.
# https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp6brwd2e0
# Downloading:   0%|          | 0.00/399 [00:00<?, ?B/s]
# storing https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/58308abdd398f5feffa9aaff656219b64ebd9236ce9da250378bf5d560485a10.a5d1dac1ca7c1325c3e25e67943f907355e16d3ce944debef21145a8e417ec71
# creating metadata file for /root/.cache/huggingface/transformers/58308abdd398f5feffa9aaff656219b64ebd9236ce9da250378bf5d560485a10.a5d1dac1ca7c1325c3e25e67943f907355e16d3ce944debef21145a8e417ec71
# https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpy1msz480
# Downloading:   0%|          | 0.00/8.66M [00:00<?, ?B/s]
# storing https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/tokenizer.json in cache at /root/.cache/huggingface/transformers/2fffb1a5f7088f56e8cf5dc66ec6591aa646135b32a7303334a91515de51e4b9.2dedbd3aa2bb53e8e26ed0125daf18f6d4aeeeeb98252d7ce59b3a63d810a963
# creating metadata file for /root/.cache/huggingface/transformers/2fffb1a5f7088f56e8cf5dc66ec6591aa646135b32a7303334a91515de51e4b9.2dedbd3aa2bb53e8e26ed0125daf18f6d4aeeeeb98252d7ce59b3a63d810a963
# https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmps717yk68
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# storing https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/special_tokens_map.json in cache at /root/.cache/huggingface/transformers/650b29e8bb4961f982ce7a003c8ff1fb431803ef3eedb3740f602256eaee04ef.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# creating metadata file for /root/.cache/huggingface/transformers/650b29e8bb4961f982ce7a003c8ff1fb431803ef3eedb3740f602256eaee04ef.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# loading file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/sentencepiece.bpe.model from cache at None
# loading file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/2fffb1a5f7088f56e8cf5dc66ec6591aa646135b32a7303334a91515de51e4b9.2dedbd3aa2bb53e8e26ed0125daf18f6d4aeeeeb98252d7ce59b3a63d810a963
# loading file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/650b29e8bb4961f982ce7a003c8ff1fb431803ef3eedb3740f602256eaee04ef.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# loading file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/58308abdd398f5feffa9aaff656219b64ebd9236ce9da250378bf5d560485a10.a5d1dac1ca7c1325c3e25e67943f907355e16d3ce944debef21145a8e417ec71
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
split = "test"
map_datasets(langs, split, prepare_validation_features)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
results_zero_shot_xlm_r_large = compute_results(langs, split)
print(results_zero_shot_xlm_r_large)
# Out:
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 448
#   Batch size = 16
#     <div>
#
#       <progress value='335' max='28' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [28/28 06:38]
#     </div>
# Post-processing 440 example predictions split into 448 features.
#   0%|          | 0/440 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 968
#   Batch size = 16
# Post-processing 921 example predictions split into 968 features.
#   0%|          | 0/921 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 127
#   Batch size = 16
# Post-processing 113 example predictions split into 127 features.
#   0%|          | 0/113 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 802
#   Batch size = 16
# Post-processing 782 example predictions split into 802 features.
#   0%|          | 0/782 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 577
#   Batch size = 16
# Post-processing 565 example predictions split into 577 features.
#   0%|          | 0/565 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 294
#   Batch size = 16
# Post-processing 276 example predictions split into 294 features.
#   0%|          | 0/276 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 862
#   Batch size = 16
# Post-processing 812 example predictions split into 862 features.
#   0%|          | 0/812 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 501
#   Batch size = 16
# Post-processing 499 example predictions split into 501 features.
#   0%|          | 0/499 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 715
#   Batch size = 16
# Post-processing 669 example predictions split into 715 features.
#   0%|          | 0/669 [00:00<?, ?it/s]
# {'en': {'exact_match': 70.9090909090909, 'f1': 81.42476230317402}, 'ar': {'exact_match': 64.06080347448426, 'f1': 78.23605283669022}, 'bn': {'exact_match': 60.176991150442475, 'f1': 75.32447886430187}, 'fi': {'exact_match': 68.54219948849105, 'f1': 79.82322469347791}, 'id': {'exact_match': 68.67256637168141, 'f1': 81.7418885889774}, 'ko': {'exact_match': 61.95652173913044, 'f1': 72.91558336010017}, 'ru': {'exact_match': 52.58620689655172, 'f1': 73.11561676207211}, 'sw': {'exact_match': 71.9438877755511, 'f1': 81.59494865936612}, 'te': {'exact_match': 67.1150971599402, 'f1': 80.82765705820313}}

# %%
df_results_zero_shot_xlm_r_large = results_df(results_zero_shot_xlm_r_large, "Zero-shot XLM-R Large")
df_results_zero_shot_xlm_r_large.to_csv("results/tydiqa/results_zero_shot_xlm_r_large.csv")
df_results_zero_shot_xlm_r_large
# Out:
#   lang  F1_Zero-shot XLM-R Large  EM_Zero-shot XLM-R Large
# 0   en                     81.42                     70.91
# 1   ar                     78.24                     64.06
# 2   bn                     75.32                     60.18
# 3   fi                     79.82                     68.54
# 4   id                     81.74                     68.67
# 5   ko                     72.92                     61.96
# 6   ru                     73.12                     52.59
# 7   sw                     81.59                     71.94
# 8   te                     80.83                     67.12
# 9  avg                     78.33                     65.11

# %% [markdown]
# ## Translate Test BERT
#
# We use the model fine-tuned on SQuAD and evaluate it on test data that we translated from the target language to English. In this case we use a monolingual BERT model, because we only evaluate on English data.

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "rsvp-ai/bertserini-bert-base-squad"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="bertserini-bert-base-squad",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp4ypo3df_
# Downloading:   0%|          | 0.00/477 [00:00<?, ?B/s]
# storing https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/ed70b9dc9bc27dc87b2280c39cf44cf6a203a269dedcd004633a5eec0898d233.1afc8e7ce4fe9efe54e1f9ac968f42b33a2baac9f294d23e1123658693b0ec80
# creating metadata file for /root/.cache/huggingface/transformers/ed70b9dc9bc27dc87b2280c39cf44cf6a203a269dedcd004633a5eec0898d233.1afc8e7ce4fe9efe54e1f9ac968f42b33a2baac9f294d23e1123658693b0ec80
# loading configuration file https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/ed70b9dc9bc27dc87b2280c39cf44cf6a203a269dedcd004633a5eec0898d233.1afc8e7ce4fe9efe54e1f9ac968f42b33a2baac9f294d23e1123658693b0ec80
# Model config BertConfig {
#   "_name_or_path": "rsvp-ai/bertserini-bert-base-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpzojdcki7
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# storing https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/aaf6ccc87650d45ada631bd3429b555eec15468ee1bb6bd140ff9b52c536b144.69af727f9c1dca3f38f6fbcf677d3b13cec34da7ecee8cc12f8354afdab53d05
# creating metadata file for /root/.cache/huggingface/transformers/aaf6ccc87650d45ada631bd3429b555eec15468ee1bb6bd140ff9b52c536b144.69af727f9c1dca3f38f6fbcf677d3b13cec34da7ecee8cc12f8354afdab53d05
# loading weights file https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/aaf6ccc87650d45ada631bd3429b555eec15468ee1bb6bd140ff9b52c536b144.69af727f9c1dca3f38f6fbcf677d3b13cec34da7ecee8cc12f8354afdab53d05
# All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# All the weights of BertForQuestionAnswering were initialized from the model checkpoint at rsvp-ai/bertserini-bert-base-squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpcmxw2z91
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# storing https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/2d7733b203aba37006a59a06ac69c1e3f6c58573fcd1c74966de7c60a062eda4.76ea01b4b85ac16e2cec55c398cba7a943d89ab21dfdd973f6630a152e4b9aed
# creating metadata file for /root/.cache/huggingface/transformers/2d7733b203aba37006a59a06ac69c1e3f6c58573fcd1c74966de7c60a062eda4.76ea01b4b85ac16e2cec55c398cba7a943d89ab21dfdd973f6630a152e4b9aed
# loading configuration file https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/ed70b9dc9bc27dc87b2280c39cf44cf6a203a269dedcd004633a5eec0898d233.1afc8e7ce4fe9efe54e1f9ac968f42b33a2baac9f294d23e1123658693b0ec80
# Model config BertConfig {
#   "_name_or_path": "rsvp-ai/bertserini-bert-base-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpa_awcat1
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# storing https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/vocab.txt in cache at /root/.cache/huggingface/transformers/a12abf418f594f5c5f313a7891155f36f4e2323344ba8bbccef96c9a16836b1c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# creating metadata file for /root/.cache/huggingface/transformers/a12abf418f594f5c5f313a7891155f36f4e2323344ba8bbccef96c9a16836b1c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpg12duk_4
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# storing https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/special_tokens_map.json in cache at /root/.cache/huggingface/transformers/cb3216ccaaa64ada5cc8f070e8950773152d63bc1ad748625ce2b79395a8f4ed.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# creating metadata file for /root/.cache/huggingface/transformers/cb3216ccaaa64ada5cc8f070e8950773152d63bc1ad748625ce2b79395a8f4ed.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# loading file https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/a12abf418f594f5c5f313a7891155f36f4e2323344ba8bbccef96c9a16836b1c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# loading file https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/cb3216ccaaa64ada5cc8f070e8950773152d63bc1ad748625ce2b79395a8f4ed.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# loading file https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/2d7733b203aba37006a59a06ac69c1e3f6c58573fcd1c74966de7c60a062eda4.76ea01b4b85ac16e2cec55c398cba7a943d89ab21dfdd973f6630a152e4b9aed
# loading configuration file https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/ed70b9dc9bc27dc87b2280c39cf44cf6a203a269dedcd004633a5eec0898d233.1afc8e7ce4fe9efe54e1f9ac968f42b33a2baac9f294d23e1123658693b0ec80
# Model config BertConfig {
#   "_name_or_path": "rsvp-ai/bertserini-bert-base-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# loading configuration file https://huggingface.co/rsvp-ai/bertserini-bert-base-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/ed70b9dc9bc27dc87b2280c39cf44cf6a203a269dedcd004633a5eec0898d233.1afc8e7ce4fe9efe54e1f9ac968f42b33a2baac9f294d23e1123658693b0ec80
# Model config BertConfig {
#   "_name_or_path": "rsvp-ai/bertserini-bert-base-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
split = "translate_test"
map_datasets(langs_translate_test, split, prepare_validation_features)
# Out:
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]

# %%
results_translate_test_bert = compute_results(langs_translate_test, split)
print(results_translate_test_bert)
# Out:
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1639
#   Batch size = 16
#     <div>
#
#       <progress value='215' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [103/103 01:32]
#     </div>
# Post-processing 1594 example predictions split into 1639 features.
#   0%|          | 0/1594 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 185
#   Batch size = 16
# Post-processing 181 example predictions split into 185 features.
#   0%|          | 0/181 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1325
#   Batch size = 16
# Post-processing 1301 example predictions split into 1325 features.
#   0%|          | 0/1301 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 938
#   Batch size = 16
#     <div>
#
#       <progress value='503' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [103/103 03:35]
#     </div>
# Post-processing 925 example predictions split into 938 features.
#   0%|          | 0/925 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 419
#   Batch size = 16
# Post-processing 411 example predictions split into 419 features.
#   0%|          | 0/411 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1490
#   Batch size = 16
# Post-processing 1437 example predictions split into 1490 features.
#   0%|          | 0/1437 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 820
#   Batch size = 16
# Post-processing 820 example predictions split into 820 features.
#   0%|          | 0/820 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1156
#   Batch size = 16
# Post-processing 1135 example predictions split into 1156 features.
#   0%|          | 0/1135 [00:00<?, ?it/s]
# {'ar': {'exact_match': 49.74905897114178, 'f1': 67.20417273395888}, 'bn': {'exact_match': 64.08839779005525, 'f1': 76.6368499517671}, 'fi': {'exact_match': 57.49423520368947, 'f1': 71.19515142817997}, 'id': {'exact_match': 60.32432432432432, 'f1': 74.16866770896556}, 'ko': {'exact_match': 58.880778588807786, 'f1': 70.10995314609484}, 'ru': {'exact_match': 55.46276965901183, 'f1': 71.87970524180498}, 'sw': {'exact_match': 63.78048780487805, 'f1': 75.96244463625342}, 'te': {'exact_match': 51.10132158590309, 'f1': 63.47354652200457}}

# %%
df_results_translate_test_bert = results_df(results_translate_test_bert, "Translate-test BERT")
df_results_translate_test_bert.to_csv("results/tydiqa/results_translate_test_bert.csv")
df_results_translate_test_bert
# Out:
#   lang  F1_Translate-test BERT  EM_Translate-test BERT
# 0   ar                   67.20                   49.75
# 1   bn                   76.64                   64.09
# 2   fi                   71.20                   57.49
# 3   id                   74.17                   60.32
# 4   ko                   70.11                   58.88
# 5   ru                   71.88                   55.46
# 6   sw                   75.96                   63.78
# 7   te                   63.47                   51.10
# 8  avg                   71.33                   57.61

# %% [markdown]
# ## Translate Test BERT-large
#
# We use the model fine-tuned on SQuAD and evaluate it on test data that we translated from the target language to English. In this case we use a monolingual BERT-large model, because we only evaluate on English data.

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "bert-large-cased-whole-word-masking-finetuned-squad"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="dir-bert-large-cased-whole-word-masking-finetuned-squad",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp43m0hkmw
# Downloading:   0%|          | 0.00/634 [00:00<?, ?B/s]
# storing https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/09a6ac8433ff705d719a8e60cb1588e83d2220da2cfe95905e958496c092535c.e15ff0ac80307dd3e1ae18a41ec3b31fef893cd86ef240a21ccd2e44dc175ee5
# creating metadata file for /root/.cache/huggingface/transformers/09a6ac8433ff705d719a8e60cb1588e83d2220da2cfe95905e958496c092535c.e15ff0ac80307dd3e1ae18a41ec3b31fef893cd86ef240a21ccd2e44dc175ee5
# loading configuration file https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/09a6ac8433ff705d719a8e60cb1588e83d2220da2cfe95905e958496c092535c.e15ff0ac80307dd3e1ae18a41ec3b31fef893cd86ef240a21ccd2e44dc175ee5
# Model config BertConfig {
#   "_name_or_path": "bert-large-cased-whole-word-masking-finetuned-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpxftod0jb
# Downloading:   0%|          | 0.00/1.24G [00:00<?, ?B/s]
# storing https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/53388cf41351c777622f6d7afdf706d7d7d5c4a05a33791985136ef7dddc7c43.53f4a814c8affef829fa2203ae222c8c013fb980860c34a0043b12ba52d16f0b
# creating metadata file for /root/.cache/huggingface/transformers/53388cf41351c777622f6d7afdf706d7d7d5c4a05a33791985136ef7dddc7c43.53f4a814c8affef829fa2203ae222c8c013fb980860c34a0043b12ba52d16f0b
# loading weights file https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/53388cf41351c777622f6d7afdf706d7d7d5c4a05a33791985136ef7dddc7c43.53f4a814c8affef829fa2203ae222c8c013fb980860c34a0043b12ba52d16f0b
# All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# All the weights of BertForQuestionAnswering were initialized from the model checkpoint at bert-large-cased-whole-word-masking-finetuned-squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpajeouebh
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# storing https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/0055368eb34542f93de5eb70c2a9c3a059bd01bae2628a405905dbc882701901.ec5c189f89475aac7d8cbd243960a0655cfadc3d0474da8ff2ed0bf1699c2a5f
# creating metadata file for /root/.cache/huggingface/transformers/0055368eb34542f93de5eb70c2a9c3a059bd01bae2628a405905dbc882701901.ec5c189f89475aac7d8cbd243960a0655cfadc3d0474da8ff2ed0bf1699c2a5f
# loading configuration file https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/09a6ac8433ff705d719a8e60cb1588e83d2220da2cfe95905e958496c092535c.e15ff0ac80307dd3e1ae18a41ec3b31fef893cd86ef240a21ccd2e44dc175ee5
# Model config BertConfig {
#   "_name_or_path": "bert-large-cased-whole-word-masking-finetuned-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpb5kq4t5r
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# storing https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/vocab.txt in cache at /root/.cache/huggingface/transformers/f77a43252a6dcf4565bb023e211c0f71c8b11ec71cae167d4e2fb1ec8dee9a87.437aa611e89f6fc6675a049d2b5545390adbc617e7d655286421c191d2be2791
# creating metadata file for /root/.cache/huggingface/transformers/f77a43252a6dcf4565bb023e211c0f71c8b11ec71cae167d4e2fb1ec8dee9a87.437aa611e89f6fc6675a049d2b5545390adbc617e7d655286421c191d2be2791
# https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp4tk20e3r
# Downloading:   0%|          | 0.00/426k [00:00<?, ?B/s]
# storing https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/tokenizer.json in cache at /root/.cache/huggingface/transformers/7e7140ff927e58a37a0862cd3dc4e2873c713af14eaf32a602d99be03d11bbb4.2b9a196704f2f183fe3f4b48d6e662dba8203fdcb3346bfa896831378edf6f97
# creating metadata file for /root/.cache/huggingface/transformers/7e7140ff927e58a37a0862cd3dc4e2873c713af14eaf32a602d99be03d11bbb4.2b9a196704f2f183fe3f4b48d6e662dba8203fdcb3346bfa896831378edf6f97
# loading file https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/f77a43252a6dcf4565bb023e211c0f71c8b11ec71cae167d4e2fb1ec8dee9a87.437aa611e89f6fc6675a049d2b5545390adbc617e7d655286421c191d2be2791
# loading file https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/7e7140ff927e58a37a0862cd3dc4e2873c713af14eaf32a602d99be03d11bbb4.2b9a196704f2f183fe3f4b48d6e662dba8203fdcb3346bfa896831378edf6f97
# loading file https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/0055368eb34542f93de5eb70c2a9c3a059bd01bae2628a405905dbc882701901.ec5c189f89475aac7d8cbd243960a0655cfadc3d0474da8ff2ed0bf1699c2a5f
# loading configuration file https://huggingface.co/bert-large-cased-whole-word-masking-finetuned-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/09a6ac8433ff705d719a8e60cb1588e83d2220da2cfe95905e958496c092535c.e15ff0ac80307dd3e1ae18a41ec3b31fef893cd86ef240a21ccd2e44dc175ee5
# Model config BertConfig {
#   "_name_or_path": "bert-large-cased-whole-word-masking-finetuned-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
split = "translate_test"
map_datasets(langs_translate_test, split, prepare_validation_features)

# %%
results_translate_test_bert_large = compute_results(langs_translate_test, split)
print(results_translate_test_bert_large)
# Out:
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1644
#   Batch size = 16
#     <div>
#
#       <progress value='457' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [103/103 09:28]
#     </div>
# Post-processing 1594 example predictions split into 1644 features.
#   0%|          | 0/1594 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 186
#   Batch size = 16
# Post-processing 181 example predictions split into 186 features.
#   0%|          | 0/181 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1328
#   Batch size = 16
# Post-processing 1301 example predictions split into 1328 features.
#   0%|          | 0/1301 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 943
#   Batch size = 16
# Post-processing 925 example predictions split into 943 features.
#   0%|          | 0/925 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 419
#   Batch size = 16
# Post-processing 411 example predictions split into 419 features.
#   0%|          | 0/411 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1490
#   Batch size = 16
# Post-processing 1437 example predictions split into 1490 features.
#   0%|          | 0/1437 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 820
#   Batch size = 16
# Post-processing 820 example predictions split into 820 features.
#   0%|          | 0/820 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1157
#   Batch size = 16
#     <div>
#
#       <progress value='503' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [103/103 10:24]
#     </div>
# Post-processing 1135 example predictions split into 1157 features.
#   0%|          | 0/1135 [00:00<?, ?it/s]
# {'ar': {'exact_match': 52.19573400250941, 'f1': 69.78703011264882}, 'bn': {'exact_match': 64.08839779005525, 'f1': 78.99850916425503}, 'fi': {'exact_match': 64.1813989239047, 'f1': 76.7574532576424}, 'id': {'exact_match': 62.37837837837838, 'f1': 75.95129863153748}, 'ko': {'exact_match': 63.503649635036496, 'f1': 73.74622591696539}, 'ru': {'exact_match': 60.12526096033403, 'f1': 75.26568707075182}, 'sw': {'exact_match': 69.7560975609756, 'f1': 80.886035507129}, 'te': {'exact_match': 66.16740088105728, 'f1': 79.68989356214003}}

# %%
df_results_translate_test_bert_large = results_df(results_translate_test_bert_large, "Translate-test BERT Large")
df_results_translate_test_bert_large.to_csv("results/tydiqa/results_translate_test_bert_large.csv")
df_results_translate_test_bert_large
# Out:
#   lang  F1_Translate-test BERT Large  EM_Translate-test BERT Large
# 0   ar                         69.79                         52.20
# 1   bn                         79.00                         64.09
# 2   fi                         76.76                         64.18
# 3   id                         75.95                         62.38
# 4   ko                         73.75                         63.50
# 5   ru                         75.27                         60.13
# 6   sw                         80.89                         69.76
# 7   te                         79.69                         66.17
# 8  avg                         76.39                         62.80

# %% [markdown]
# ## Translate Test RoBERTa
#
# We use the model fine-tuned on SQuAD and evaluate it on test data that we translated from the target language to English. In this case we use a monolingual RoBERTa model, because we only evaluate on English data.

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "thatdramebaazguy/roberta-base-squad"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="roberta-base-squad",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp0dhlijzs
# Downloading:   0%|          | 0.00/720 [00:00<?, ?B/s]
# storing https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/892dedc3d4dc51337f07712ae60bee9d35540607c674cf14c1e8fa759c8044f6.143a3b91b00882c22e382aa9dce198fca4876a0147d4208940720f26038eecea
# creating metadata file for /root/.cache/huggingface/transformers/892dedc3d4dc51337f07712ae60bee9d35540607c674cf14c1e8fa759c8044f6.143a3b91b00882c22e382aa9dce198fca4876a0147d4208940720f26038eecea
# loading configuration file https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/892dedc3d4dc51337f07712ae60bee9d35540607c674cf14c1e8fa759c8044f6.143a3b91b00882c22e382aa9dce198fca4876a0147d4208940720f26038eecea
# Model config RobertaConfig {
#   "_name_or_path": "thatdramebaazguy/roberta-base-squad",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpfhh01w0x
# Downloading:   0%|          | 0.00/473M [00:00<?, ?B/s]
# storing https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/eae6ec0ceba7122f93f8ba10ea14828355c6db5ccbe45329df98c66acc6dec1c.e2c6aeaa07a1eaf01009558b402d71dc19744520a98718fc20f5d6777489a1c0
# creating metadata file for /root/.cache/huggingface/transformers/eae6ec0ceba7122f93f8ba10ea14828355c6db5ccbe45329df98c66acc6dec1c.e2c6aeaa07a1eaf01009558b402d71dc19744520a98718fc20f5d6777489a1c0
# loading weights file https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/eae6ec0ceba7122f93f8ba10ea14828355c6db5ccbe45329df98c66acc6dec1c.e2c6aeaa07a1eaf01009558b402d71dc19744520a98718fc20f5d6777489a1c0
# All model checkpoint weights were used when initializing RobertaForQuestionAnswering.
#
# All the weights of RobertaForQuestionAnswering were initialized from the model checkpoint at thatdramebaazguy/roberta-base-squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForQuestionAnswering for predictions without further training.
# https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp3j2lpw4v
# Downloading:   0%|          | 0.00/288 [00:00<?, ?B/s]
# storing https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/5231bd092e0b0d99fe8cf0108e7a3c8ecf70d43cc7d2427303ff89082aea5bcb.09a955289623ccab6e7dcd938a4e61ac68eb1e2a8b7bc6bb58e3acbf359023d9
# creating metadata file for /root/.cache/huggingface/transformers/5231bd092e0b0d99fe8cf0108e7a3c8ecf70d43cc7d2427303ff89082aea5bcb.09a955289623ccab6e7dcd938a4e61ac68eb1e2a8b7bc6bb58e3acbf359023d9
# loading configuration file https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/892dedc3d4dc51337f07712ae60bee9d35540607c674cf14c1e8fa759c8044f6.143a3b91b00882c22e382aa9dce198fca4876a0147d4208940720f26038eecea
# Model config RobertaConfig {
#   "_name_or_path": "thatdramebaazguy/roberta-base-squad",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/vocab.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp1loo5ijx
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# storing https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/vocab.json in cache at /root/.cache/huggingface/transformers/1fe6670fd1703bab634d459d85ba622bc85238b2ddd5e4a959e3e8ae4236db44.bfdcc444ff249bca1a95ca170ec350b442f81804d7df3a95a2252217574121d7
# creating metadata file for /root/.cache/huggingface/transformers/1fe6670fd1703bab634d459d85ba622bc85238b2ddd5e4a959e3e8ae4236db44.bfdcc444ff249bca1a95ca170ec350b442f81804d7df3a95a2252217574121d7
# https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/merges.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp6eccbagj
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# storing https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/merges.txt in cache at /root/.cache/huggingface/transformers/52729906e4dae69dd2c4542bd269069500d1eff2e5ee45010976e928b6c7e42c.f5b91da9e34259b8f4d88dbc97c740667a0e8430b96314460cdb04e86d4fc435
# creating metadata file for /root/.cache/huggingface/transformers/52729906e4dae69dd2c4542bd269069500d1eff2e5ee45010976e928b6c7e42c.f5b91da9e34259b8f4d88dbc97c740667a0e8430b96314460cdb04e86d4fc435
# https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp_v7a5qd8
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# storing https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/special_tokens_map.json in cache at /root/.cache/huggingface/transformers/bc9c87f318c0ab6db507f08aa6e3e125ba1565b61fdbbf2f8a321dc8a4ad5ad5.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# creating metadata file for /root/.cache/huggingface/transformers/bc9c87f318c0ab6db507f08aa6e3e125ba1565b61fdbbf2f8a321dc8a4ad5ad5.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# loading file https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/vocab.json from cache at /root/.cache/huggingface/transformers/1fe6670fd1703bab634d459d85ba622bc85238b2ddd5e4a959e3e8ae4236db44.bfdcc444ff249bca1a95ca170ec350b442f81804d7df3a95a2252217574121d7
# loading file https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/merges.txt from cache at /root/.cache/huggingface/transformers/52729906e4dae69dd2c4542bd269069500d1eff2e5ee45010976e928b6c7e42c.f5b91da9e34259b8f4d88dbc97c740667a0e8430b96314460cdb04e86d4fc435
# loading file https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/bc9c87f318c0ab6db507f08aa6e3e125ba1565b61fdbbf2f8a321dc8a4ad5ad5.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# loading file https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/5231bd092e0b0d99fe8cf0108e7a3c8ecf70d43cc7d2427303ff89082aea5bcb.09a955289623ccab6e7dcd938a4e61ac68eb1e2a8b7bc6bb58e3acbf359023d9
# loading configuration file https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/892dedc3d4dc51337f07712ae60bee9d35540607c674cf14c1e8fa759c8044f6.143a3b91b00882c22e382aa9dce198fca4876a0147d4208940720f26038eecea
# Model config RobertaConfig {
#   "_name_or_path": "thatdramebaazguy/roberta-base-squad",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file https://huggingface.co/thatdramebaazguy/roberta-base-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/892dedc3d4dc51337f07712ae60bee9d35540607c674cf14c1e8fa759c8044f6.143a3b91b00882c22e382aa9dce198fca4876a0147d4208940720f26038eecea
# Model config RobertaConfig {
#   "_name_or_path": "thatdramebaazguy/roberta-base-squad",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
split = "translate_test"
map_datasets(langs_translate_test, split, prepare_validation_features)

# %%
results_translate_test_roberta = compute_results(langs_translate_test, split)
print(results_translate_test_roberta)
# Out:
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1644
#   Batch size = 16
#     <div>
#
#       <progress value='404' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [103/103 02:37]
#     </div>
# Post-processing 1594 example predictions split into 1644 features.
#   0%|          | 0/1594 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 185
#   Batch size = 16
# Post-processing 181 example predictions split into 185 features.
#   0%|          | 0/181 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1327
#   Batch size = 16
# Post-processing 1301 example predictions split into 1327 features.
#   0%|          | 0/1301 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 940
#   Batch size = 16
# Post-processing 925 example predictions split into 940 features.
#   0%|          | 0/925 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 419
#   Batch size = 16
# Post-processing 411 example predictions split into 419 features.
#   0%|          | 0/411 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1492
#   Batch size = 16
# Post-processing 1437 example predictions split into 1492 features.
#   0%|          | 0/1437 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 820
#   Batch size = 16
#     <div>
#
#       <progress value='503' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [103/103 03:14]
#     </div>
# Post-processing 820 example predictions split into 820 features.
#   0%|          | 0/820 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1157
#   Batch size = 16
# Post-processing 1135 example predictions split into 1157 features.
#   0%|          | 0/1135 [00:00<?, ?it/s]
# {'ar': {'exact_match': 47.61606022584692, 'f1': 66.88885410455094}, 'bn': {'exact_match': 57.4585635359116, 'f1': 72.41603086906954}, 'fi': {'exact_match': 60.41506533435819, 'f1': 74.32024048598824}, 'id': {'exact_match': 60.86486486486486, 'f1': 74.37363250730593}, 'ko': {'exact_match': 57.420924574209245, 'f1': 70.31024847183575}, 'ru': {'exact_match': 55.11482254697286, 'f1': 71.58815159744569}, 'sw': {'exact_match': 66.95121951219512, 'f1': 78.55489795727458}, 'te': {'exact_match': 55.50660792951542, 'f1': 69.15306069646554}}

# %%
df_results_translate_test_roberta = results_df(results_translate_test_roberta, "Translate-test RoBERTa")
df_results_translate_test_roberta.to_csv("results/tydiqa/results_translate_test_roberta.csv")
df_results_translate_test_roberta
# Out:
#   lang  F1_Translate-test RoBERTa  EM_Translate-test RoBERTa
# 0   ar                      66.89                      47.62
# 1   bn                      72.42                      57.46
# 2   fi                      74.32                      60.42
# 3   id                      74.37                      60.86
# 4   ko                      70.31                      57.42
# 5   ru                      71.59                      55.11
# 6   sw                      78.55                      66.95
# 7   te                      69.15                      55.51
# 8  avg                      72.20                      57.67

# %% [markdown]
# ## Translate Test RoBERTa-large
#
# We use the model fine-tuned on SQuAD and evaluate it on test data that we translated from the target language to English. In this case we use a monolingual RoBERTa-large model, because we only evaluate on English data.

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "csarron/roberta-large-squad-v1"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="roberta-large-squad-v1",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp07hwy6lr
# Downloading:   0%|          | 0.00/526 [00:00<?, ?B/s]
# storing https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/0fc041ca661ebb7473123e9722819c48e27f9a83aedf13e1150435275cc21bdd.e59dc72a749f921962e2e724ff292de7eb1b9902723153972b2069e8847ff4f0
# creating metadata file for /root/.cache/huggingface/transformers/0fc041ca661ebb7473123e9722819c48e27f9a83aedf13e1150435275cc21bdd.e59dc72a749f921962e2e724ff292de7eb1b9902723153972b2069e8847ff4f0
# loading configuration file https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/0fc041ca661ebb7473123e9722819c48e27f9a83aedf13e1150435275cc21bdd.e59dc72a749f921962e2e724ff292de7eb1b9902723153972b2069e8847ff4f0
# Model config RobertaConfig {
#   "_name_or_path": "csarron/roberta-large-squad-v1",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmphdvc1bsl
# Downloading:   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# storing https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/935ac7e3a963d7bbb378084e7fd258dff35107d1f2adf0330552dccd9d042b67.dcb0046418df96c9fb3968477de7cd19a4f6ccb9b4796bca32743ccf081b9859
# creating metadata file for /root/.cache/huggingface/transformers/935ac7e3a963d7bbb378084e7fd258dff35107d1f2adf0330552dccd9d042b67.dcb0046418df96c9fb3968477de7cd19a4f6ccb9b4796bca32743ccf081b9859
# loading weights file https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/935ac7e3a963d7bbb378084e7fd258dff35107d1f2adf0330552dccd9d042b67.dcb0046418df96c9fb3968477de7cd19a4f6ccb9b4796bca32743ccf081b9859
# All model checkpoint weights were used when initializing RobertaForQuestionAnswering.
#
# All the weights of RobertaForQuestionAnswering were initialized from the model checkpoint at csarron/roberta-large-squad-v1.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForQuestionAnswering for predictions without further training.
# https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp6sqd8q57
# Downloading:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# storing https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/d83af4fbe61613dfaf70774340a396b54325045622496964fb17caa959c6f04c.25d8d06fb0679146a3ed2a3463e3585380bff882fe6e1ebc497196e40dbbd7fa
# creating metadata file for /root/.cache/huggingface/transformers/d83af4fbe61613dfaf70774340a396b54325045622496964fb17caa959c6f04c.25d8d06fb0679146a3ed2a3463e3585380bff882fe6e1ebc497196e40dbbd7fa
# loading configuration file https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/0fc041ca661ebb7473123e9722819c48e27f9a83aedf13e1150435275cc21bdd.e59dc72a749f921962e2e724ff292de7eb1b9902723153972b2069e8847ff4f0
# Model config RobertaConfig {
#   "_name_or_path": "csarron/roberta-large-squad-v1",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/vocab.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpk8487fot
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# storing https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/vocab.json in cache at /root/.cache/huggingface/transformers/5e33c3e3fc394fe42529078e25b17308c41253999ae658832e1d00c1e35e2f23.647b4548b6d9ea817e82e7a9231a320231a1c9ea24053cc9e758f3fe68216f05
# creating metadata file for /root/.cache/huggingface/transformers/5e33c3e3fc394fe42529078e25b17308c41253999ae658832e1d00c1e35e2f23.647b4548b6d9ea817e82e7a9231a320231a1c9ea24053cc9e758f3fe68216f05
# https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/merges.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp0_b48moz
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# storing https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/merges.txt in cache at /root/.cache/huggingface/transformers/48047eb6f8b799c467d0f97316aa9b6e520be6ace95983203d421834eb0c0b54.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# creating metadata file for /root/.cache/huggingface/transformers/48047eb6f8b799c467d0f97316aa9b6e520be6ace95983203d421834eb0c0b54.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpp_alytar
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# storing https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/special_tokens_map.json in cache at /root/.cache/huggingface/transformers/030f51904149258d64958d23a91fbc76c0fe866b3a4c2605c337b5adbb330e3e.cb2244924ab24d706b02fd7fcedaea4531566537687a539ebb94db511fd122a0
# creating metadata file for /root/.cache/huggingface/transformers/030f51904149258d64958d23a91fbc76c0fe866b3a4c2605c337b5adbb330e3e.cb2244924ab24d706b02fd7fcedaea4531566537687a539ebb94db511fd122a0
# loading file https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/vocab.json from cache at /root/.cache/huggingface/transformers/5e33c3e3fc394fe42529078e25b17308c41253999ae658832e1d00c1e35e2f23.647b4548b6d9ea817e82e7a9231a320231a1c9ea24053cc9e758f3fe68216f05
# loading file https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/merges.txt from cache at /root/.cache/huggingface/transformers/48047eb6f8b799c467d0f97316aa9b6e520be6ace95983203d421834eb0c0b54.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b
# loading file https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/030f51904149258d64958d23a91fbc76c0fe866b3a4c2605c337b5adbb330e3e.cb2244924ab24d706b02fd7fcedaea4531566537687a539ebb94db511fd122a0
# loading file https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/d83af4fbe61613dfaf70774340a396b54325045622496964fb17caa959c6f04c.25d8d06fb0679146a3ed2a3463e3585380bff882fe6e1ebc497196e40dbbd7fa
# loading configuration file https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/0fc041ca661ebb7473123e9722819c48e27f9a83aedf13e1150435275cc21bdd.e59dc72a749f921962e2e724ff292de7eb1b9902723153972b2069e8847ff4f0
# Model config RobertaConfig {
#   "_name_or_path": "csarron/roberta-large-squad-v1",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading configuration file https://huggingface.co/csarron/roberta-large-squad-v1/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/0fc041ca661ebb7473123e9722819c48e27f9a83aedf13e1150435275cc21bdd.e59dc72a749f921962e2e724ff292de7eb1b9902723153972b2069e8847ff4f0
# Model config RobertaConfig {
#   "_name_or_path": "csarron/roberta-large-squad-v1",
#   "architectures": [
#     "RobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
split = "translate_test"
map_datasets(langs_translate_test, split, prepare_validation_features)

# %%
results_translate_test_roberta_large = compute_results(langs_translate_test, split)
print(results_translate_test_roberta_large)
# Out:
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1644
#   Batch size = 16
#     <div>
#
#       <progress value='481' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [103/103 09:28]
#     </div>
# Post-processing 1594 example predictions split into 1644 features.
#   0%|          | 0/1594 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 185
#   Batch size = 16
# Post-processing 181 example predictions split into 185 features.
#   0%|          | 0/181 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1327
#   Batch size = 16
# Post-processing 1301 example predictions split into 1327 features.
#   0%|          | 0/1301 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 940
#   Batch size = 16
# Post-processing 925 example predictions split into 940 features.
#   0%|          | 0/925 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 419
#   Batch size = 16
# Post-processing 411 example predictions split into 419 features.
#   0%|          | 0/411 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1492
#   Batch size = 16
# Post-processing 1437 example predictions split into 1492 features.
#   0%|          | 0/1437 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 820
#   Batch size = 16
# Post-processing 820 example predictions split into 820 features.
#   0%|          | 0/820 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1157
#   Batch size = 16
#     <div>
#
#       <progress value='503' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [103/103 09:53]
#     </div>
# Post-processing 1135 example predictions split into 1157 features.
#   0%|          | 0/1135 [00:00<?, ?it/s]
# {'ar': {'exact_match': 48.117942283563366, 'f1': 66.9108092960345}, 'bn': {'exact_match': 62.98342541436464, 'f1': 78.06048196872125}, 'fi': {'exact_match': 60.6456571867794, 'f1': 75.36224915028285}, 'id': {'exact_match': 56.75675675675676, 'f1': 72.9949946152018}, 'ko': {'exact_match': 61.557177615571774, 'f1': 73.19095147590308}, 'ru': {'exact_match': 58.107167710508, 'f1': 74.33753710594873}, 'sw': {'exact_match': 69.63414634146342, 'f1': 80.18428742837976}, 'te': {'exact_match': 63.17180616740088, 'f1': 77.96149925914105}}

# %%
df_results_translate_test_roberta_large = results_df(results_translate_test_roberta_large, "Translate-test RoBERTa Large")
df_results_translate_test_roberta_large.to_csv("results/tydiqa/results_translate_test_roberta_large.csv")
df_results_translate_test_roberta_large
# Out:
#   lang  F1_Translate-test RoBERTa Large  EM_Translate-test RoBERTa Large
# 0   ar                            66.91                            48.12
# 1   bn                            78.06                            62.98
# 2   fi                            75.36                            60.65
# 3   id                            72.99                            56.76
# 4   ko                            73.19                            61.56
# 5   ru                            74.34                            58.11
# 6   sw                            80.18                            69.63
# 7   te                            77.96                            63.17
# 8  avg                            74.88                            60.12

# %% [markdown]
# ## Translate Test mBERT
#
# We use the model fine-tuned on SQuAD and evaluate it on test data that we translated from the target language to English. In this case we  use mBERT, but we could also use a monolingual model, because we only evaluate on English data.

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "salti/bert-base-multilingual-cased-finetuned-squad"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="bert-base-multilingual-cased-finetuned-squad",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# loading configuration file https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/1df6572a9ae2fd1152d4fa4e3b9d30e0d303c69cb87d5b8401ef5cb032016bef.aa91fcc51e661ddbf70fda4906759b1d8178a512385633adf5d0db934ae1e333
# Model config BertConfig {
#   "_name_or_path": "salti/bert-base-multilingual-cased-finetuned-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 119547
# }
#
# loading weights file https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/9f54849aca742a855728dc8a74c1a733627678a2e8c7a97ba60e2b318ad1438a.b9c031b09975cb84030a5da7731e0b35844cbf7eed5f7ddc0dc0704ba6cc5802
# All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# All the weights of BertForQuestionAnswering were initialized from the model checkpoint at salti/bert-base-multilingual-cased-finetuned-squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# loading configuration file https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/1df6572a9ae2fd1152d4fa4e3b9d30e0d303c69cb87d5b8401ef5cb032016bef.aa91fcc51e661ddbf70fda4906759b1d8178a512385633adf5d0db934ae1e333
# Model config BertConfig {
#   "_name_or_path": "salti/bert-base-multilingual-cased-finetuned-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 119547
# }
#
# loading file https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/f4a09a359df2eb92d135ea2d1092b9f0f3388951f8612fd97e9b071eaa3c3c98.6c5b6600e968f4b5e08c86d8891ea99e51537fc2bf251435fb46922e8f7a7b29
# loading file https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/33bece2c5789380abddaab5941fb528198297c167ddfa9547ab37dd92f940b55.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# loading file https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/834c4d17cccdc848e5ac1e4978b371d9d3afa3bb371fe8f6be85119e3a0ea885.c60f034cf5bf819518a0170960ddb62b4576fa3d01e9021876b801600cbb6f42
# loading configuration file https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/1df6572a9ae2fd1152d4fa4e3b9d30e0d303c69cb87d5b8401ef5cb032016bef.aa91fcc51e661ddbf70fda4906759b1d8178a512385633adf5d0db934ae1e333
# Model config BertConfig {
#   "_name_or_path": "salti/bert-base-multilingual-cased-finetuned-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 119547
# }
#
# loading configuration file https://huggingface.co/salti/bert-base-multilingual-cased-finetuned-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/1df6572a9ae2fd1152d4fa4e3b9d30e0d303c69cb87d5b8401ef5cb032016bef.aa91fcc51e661ddbf70fda4906759b1d8178a512385633adf5d0db934ae1e333
# Model config BertConfig {
#   "_name_or_path": "salti/bert-base-multilingual-cased-finetuned-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 119547
# }
#
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
split = "translate_test"
map_datasets(langs_translate_test, split, prepare_validation_features)

# %%
results_translate_test_mbert = compute_results(langs_translate_test, split)
print(results_translate_test_mbert)
# Out:
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1643
#   Batch size = 16
#     <div>
#
#       <progress value='201' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [103/103 01:24]
#     </div>
# Post-processing 1594 example predictions split into 1643 features.
#   0%|          | 0/1594 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 185
#   Batch size = 16
# Post-processing 181 example predictions split into 185 features.
#   0%|          | 0/181 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1323
#   Batch size = 16
# Post-processing 1301 example predictions split into 1323 features.
#   0%|          | 0/1301 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 941
#   Batch size = 16
#     <div>
#
#       <progress value='503' max='103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [103/103 03:32]
#     </div>
# Post-processing 925 example predictions split into 941 features.
#   0%|          | 0/925 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 422
#   Batch size = 16
# Post-processing 411 example predictions split into 422 features.
#   0%|          | 0/411 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1491
#   Batch size = 16
# Post-processing 1437 example predictions split into 1491 features.
#   0%|          | 0/1437 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 820
#   Batch size = 16
# Post-processing 820 example predictions split into 820 features.
#   0%|          | 0/820 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1155
#   Batch size = 16
# Post-processing 1135 example predictions split into 1155 features.
#   0%|          | 0/1135 [00:00<?, ?it/s]
# {'ar': {'exact_match': 48.93350062735257, 'f1': 66.66492757238873}, 'bn': {'exact_match': 56.353591160220994, 'f1': 70.4351163359596}, 'fi': {'exact_match': 61.64488854727133, 'f1': 73.22898855359024}, 'id': {'exact_match': 59.13513513513514, 'f1': 72.8971735187752}, 'ko': {'exact_match': 60.34063260340633, 'f1': 71.87281682814871}, 'ru': {'exact_match': 55.53235908141962, 'f1': 71.94962093623509}, 'sw': {'exact_match': 68.41463414634147, 'f1': 79.7753884806548}, 'te': {'exact_match': 54.97797356828194, 'f1': 66.86637016204246}}

# %%
df_results_translate_test_mbert = results_df(results_translate_test_mbert, "Translate-test mBERT")
df_results_translate_test_mbert.to_csv("results/tydiqa/results_translate_test_mbert.csv")
df_results_translate_test_mbert
# Out:
#   lang  F1_Translate-test mBERT  EM_Translate-test mBERT
# 0   ar                    66.66                    48.93
# 1   bn                    70.44                    56.35
# 2   fi                    73.23                    61.64
# 3   id                    72.90                    59.14
# 4   ko                    71.87                    60.34
# 5   ru                    71.95                    55.53
# 6   sw                    79.78                    68.41
# 7   te                    66.87                    54.98
# 8  avg                    71.71                    58.17

# %% [markdown]
# ## Translate Test XLM-R
#
# We use the model fine-tuned on SQuAD and evaluate it on test data that we translated from the target language to English. In this case we  use XLM-R, but we could also use a monolingual model, because we only evaluate on English data.

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "vanichandna/xlm-roberta-finetuned-squad"
model = AutoModelForQuestionAnswering.from_pretrained(model_name,from_tf=True)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="xlm-roberta-finetuned-squad",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# loading configuration file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/6e9fab04c4168068e4162152496d68d0594b8a838953657e9234b70b2c4932fb.b04b4828cf6cfcbbcba34b7e4fc29fe9a0563001f3cedda0f9cf6487875eae92
# Model config XLMRobertaConfig {
#   "_name_or_path": "vanichandna/xlm-roberta-finetuned-squad",
#   "architectures": [
#     "XLMRobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# loading weights file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/tf_model.h5 from cache at /root/.cache/huggingface/transformers/40231dec3bc81ec27bf1027247098bd684738dffa5f2296b2cad573879d0c229.fdcf91f65f36389325caf97398f95d17232f926dca8f8ecac72019c5ca36ba9d.h5
# Loading TensorFlow weights from /root/.cache/huggingface/transformers/40231dec3bc81ec27bf1027247098bd684738dffa5f2296b2cad573879d0c229.fdcf91f65f36389325caf97398f95d17232f926dca8f8ecac72019c5ca36ba9d.h5
# All TF 2.0 model weights were used when initializing XLMRobertaForQuestionAnswering.
#
# All the weights of XLMRobertaForQuestionAnswering were initialized from the TF 2.0 model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use XLMRobertaForQuestionAnswering for predictions without further training.
# Weights or buffers not loaded from TF 2.0 model: set()
# loading file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/sentencepiece.bpe.model from cache at None
# loading file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/7f7f92d02ee98c92db3e0ef5445a40b8301c4206d4df0adc2bbb55b109b17dc3.d9915425c8f75472760a4bb40b4d5d0b3ab357a1b00aaf7917cda68403cbc936
# loading file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/21e94506b48b2fcd8bf2ffb7d2216e68cb34dd50b493e0cdbffbb6c97efd961b.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# loading file https://huggingface.co/vanichandna/xlm-roberta-finetuned-squad/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/14a0caad62ab9246eaaf3d48369dcfa9230e8c7a75c21a5a5b984e9b681a780b.b36482fbec4a714d3cfec99e0b05f4fdeec9e759090a78aed5597583a8b4783d
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
split = "translate_test"
map_datasets(langs_translate_test, split, prepare_validation_features)

# %%
results_translate_test_xlm_r = compute_results(langs_translate_test, split)
print(results_translate_test_xlm_r)
# Out:
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1659
#   Batch size = 16
#     <div>
#
#       <progress value='337' max='104' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [104/104 02:11]
#     </div>
# Post-processing 1594 example predictions split into 1659 features.
#   0%|          | 0/1594 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 187
#   Batch size = 16
# Post-processing 181 example predictions split into 187 features.
#   0%|          | 0/181 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1325
#   Batch size = 16
# Post-processing 1301 example predictions split into 1325 features.
#   0%|          | 0/1301 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 944
#   Batch size = 16
# Post-processing 925 example predictions split into 944 features.
#   0%|          | 0/925 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 423
#   Batch size = 16
# Post-processing 411 example predictions split into 423 features.
#   0%|          | 0/411 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1504
#   Batch size = 16
#     <div>
#
#       <progress value='504' max='104' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [104/104 03:17]
#     </div>
# Post-processing 1437 example predictions split into 1504 features.
#   0%|          | 0/1437 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 820
#   Batch size = 16
# Post-processing 820 example predictions split into 820 features.
#   0%|          | 0/820 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 1157
#   Batch size = 16
# Post-processing 1135 example predictions split into 1157 features.
#   0%|          | 0/1135 [00:00<?, ?it/s]
# {'ar': {'exact_match': 46.361355081555836, 'f1': 63.5874345900854}, 'bn': {'exact_match': 60.773480662983424, 'f1': 72.45023239498379}, 'fi': {'exact_match': 56.8793235972329, 'f1': 69.5733386457648}, 'id': {'exact_match': 58.270270270270274, 'f1': 71.23788016719686}, 'ko': {'exact_match': 56.2043795620438, 'f1': 69.55599648606449}, 'ru': {'exact_match': 55.11482254697286, 'f1': 70.85153358674224}, 'sw': {'exact_match': 68.90243902439025, 'f1': 78.78484961541594}, 'te': {'exact_match': 46.784140969163, 'f1': 59.44741305764594}}

# %%
df_results_translate_test_xlm_r = results_df(results_translate_test_xlm_r, "Translate-test XLM-R")
df_results_translate_test_xlm_r.to_csv("results/tydiqa/results_translate_test_xlm_r.csv")
df_results_translate_test_xlm_r
# Out:
#   lang  F1_Translate-test XLM-R  EM_Translate-test XLM-R
# 0   ar                    63.59                    46.36
# 1   bn                    72.45                    60.77
# 2   fi                    69.57                    56.88
# 3   id                    71.24                    58.27
# 4   ko                    69.56                    56.20
# 5   ru                    70.85                    55.11
# 6   sw                    78.78                    68.90
# 7   te                    59.45                    46.78
# 8  avg                    69.44                    56.16

# %% [markdown]
# ## Translate Test XLM-R-large
#
# We use the model fine-tuned on SQuAD and evaluate it on test data that we translated from the target language to English. In this case we use XLM-R-large, but we could also use a monolingual model, because we only evaluate on English data.

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "Palak/xlm-roberta-large_squad"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="xlm-roberta-large_squad",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# loading configuration file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/15ba31e9d5d227c3e7514429b9e154b4dd9fa20dc6634e2aa859a6570580ab8a.e0ee6561aeb1e6c81ca8555d0aed71ddc7b312c694416a29b2dd0b16df13a0b3
# Model config XLMRobertaConfig {
#   "_name_or_path": "Palak/xlm-roberta-large_squad",
#   "architectures": [
#     "XLMRobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# loading weights file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/8edefbae0f1cc20d5925e7aeb8dd97881317810b29b16f0b519cabf0cd976fcb.7a0fe9d2258fd179f0fd3372c78a7daa343f8f5fcacba19a70f8f4bfcfa6a3a6
# All model checkpoint weights were used when initializing XLMRobertaForQuestionAnswering.
#
# All the weights of XLMRobertaForQuestionAnswering were initialized from the model checkpoint at Palak/xlm-roberta-large_squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use XLMRobertaForQuestionAnswering for predictions without further training.
# loading file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/sentencepiece.bpe.model from cache at None
# loading file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/2fffb1a5f7088f56e8cf5dc66ec6591aa646135b32a7303334a91515de51e4b9.2dedbd3aa2bb53e8e26ed0125daf18f6d4aeeeeb98252d7ce59b3a63d810a963
# loading file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/650b29e8bb4961f982ce7a003c8ff1fb431803ef3eedb3740f602256eaee04ef.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# loading file https://huggingface.co/Palak/xlm-roberta-large_squad/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/58308abdd398f5feffa9aaff656219b64ebd9236ce9da250378bf5d560485a10.a5d1dac1ca7c1325c3e25e67943f907355e16d3ce944debef21145a8e417ec71
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
split = "translate_test"
map_datasets(langs_translate_test, split, prepare_validation_features)

# %%
results_translate_test_xlm_r_large = compute_results(langs_translate_test, split)
print(results_translate_test_xlm_r_large)

# %%
df_results_translate_test_xlm_r_large = results_df(results_translate_test_xlm_r_large, "Translate-test XLM-R Large")
df_results_translate_test_xlm_r_large.to_csv("results/tydiqa/results_translate_test_xlm_r_large.csv")
df_results_translate_test_xlm_r_large
# Out:
#   lang  F1_Translate-test XLM-R Large  EM_Translate-test XLM-R Large
# 0   ar                          68.59                          52.51
# 1   bn                          73.28                          58.01
# 2   fi                          75.23                          61.26
# 3   id                          75.50                          62.92
# 4   ko                          68.47                          56.69
# 5   ru                          73.81                          58.66
# 6   sw                          80.18                          69.51
# 7   te                          76.56                          61.76
# 8  avg                          73.95                          60.17

# %% [markdown]
# ## Translate Train Es mBERT
#
# For many language pairs, a MT model may be available, which can be used to obtain data in the target language. To evaluate the impact of using such data, we translate the English training data into the target language using our MT system. We then fine-tune mBERT on the translated data. We must align answer spans in the source and target language for the QA tasks. We use data that was already translated to save time.

# %% [markdown]
# Now that our data is ready for training, we can download the pretrained model and fine-tune it. Since our task is question answering, we use the `AutoModelForQuestionAnswering` class. Like with the tokenizer, the `from_pretrained` method will download and cache the model for us:

# %%
from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer

model_name = "bert-base-multilingual-cased"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

batch_size = 16

training_args = TrainingArguments(
    output_dir="bert-base-multilingual-cased-squad-es",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
    # push_to_hub=True
)

# %% [markdown]
# Use 🤗 Datasets map function to apply the preprocessing function over the entire dataset. You can speed up the map function by setting `batched=True` to process multiple elements of the dataset at once. Remove the columns you don’t need.

# %%
lang = ["es"]

split = "translate_train"
map_datasets(lang, split, prepare_train_features)

split = "translate_dev"
map_datasets(lang, split, prepare_train_features)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tydiqa_prep["es"]["translate_train"],
    eval_dataset=tydiqa_prep["es"]["translate_dev"],
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# %%
# trainer.train()

# %%
split = "test"
map_datasets(langs, split, prepare_validation_features)

# %%
split = "test"
results_translate_train_es_mbert = compute_results(langs, split)
print(results_translate_train_es_mbert)

# %%
df_results_translate_train_es_mbert = results_df(results_translate_train_es_mbert, "Translate-train es mBERT")
df_results_translate_train_es_mbert.to_csv("results/tydiqa/results_translate_train_es_mbert.csv")
df_results_translate_train_es_mbert

# %%
# trainer.push_to_hub()

# %% [markdown]
# ## Translate Train Es XLM-R
#
# For many language pairs, a MT model may be available, which can be used to obtain data in the target language. To evaluate the impact of using such data, we translate the English training data into the target language using our MT system. We use a XLM-R model that has already been finetuned to save time.

# %% [markdown]
# Now that our data is ready for training, we can download the pretrained model and fine-tune it. Since our task is question answering, we use the `AutoModelForQuestionAnswering` class. Like with the tokenizer, the `from_pretrained` method will download and cache the model for us:

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "saattrupdan/xlmr-base-texas-squad-es"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="bert-multi-cased-finetuned-tydiqav1",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpklbahnge
# Downloading:   0%|          | 0.00/716 [00:00<?, ?B/s]
# storing https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/faf74a33d110680ea7f72791fa918036c0fd9edbcbdbf36af3bde7c86b23a8f2.b749a309a5febb0957ff5acc5d4f5534d14f38569553b954c37647de7ea10ae4
# creating metadata file for /root/.cache/huggingface/transformers/faf74a33d110680ea7f72791fa918036c0fd9edbcbdbf36af3bde7c86b23a8f2.b749a309a5febb0957ff5acc5d4f5534d14f38569553b954c37647de7ea10ae4
# loading configuration file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/faf74a33d110680ea7f72791fa918036c0fd9edbcbdbf36af3bde7c86b23a8f2.b749a309a5febb0957ff5acc5d4f5534d14f38569553b954c37647de7ea10ae4
# Model config XLMRobertaConfig {
#   "_name_or_path": "saattrupdan/xlmr-base-texas-squad-es",
#   "architectures": [
#     "XLMRobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp8o67le08
# Downloading:   0%|          | 0.00/1.03G [00:00<?, ?B/s]
# storing https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/acdf22ff03faa9cd992d27a19088abdc9f28a3b4e1e40a14e98cfcb0b18c1403.d1cb5eddd332add5df96171f7f759027748f6b03de7b4fdd45f72ebf349e9eb3
# creating metadata file for /root/.cache/huggingface/transformers/acdf22ff03faa9cd992d27a19088abdc9f28a3b4e1e40a14e98cfcb0b18c1403.d1cb5eddd332add5df96171f7f759027748f6b03de7b4fdd45f72ebf349e9eb3
# loading weights file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/acdf22ff03faa9cd992d27a19088abdc9f28a3b4e1e40a14e98cfcb0b18c1403.d1cb5eddd332add5df96171f7f759027748f6b03de7b4fdd45f72ebf349e9eb3
# All model checkpoint weights were used when initializing XLMRobertaForQuestionAnswering.
#
# All the weights of XLMRobertaForQuestionAnswering were initialized from the model checkpoint at saattrupdan/xlmr-base-texas-squad-es.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use XLMRobertaForQuestionAnswering for predictions without further training.
# https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp1iff28ba
# Downloading:   0%|          | 0.00/398 [00:00<?, ?B/s]
# storing https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/111d92253a878f3919c5c83c05be6fe131f4d4e29e27d3994266b0581067ef7a.b36482fbec4a714d3cfec99e0b05f4fdeec9e759090a78aed5597583a8b4783d
# creating metadata file for /root/.cache/huggingface/transformers/111d92253a878f3919c5c83c05be6fe131f4d4e29e27d3994266b0581067ef7a.b36482fbec4a714d3cfec99e0b05f4fdeec9e759090a78aed5597583a8b4783d
# https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/sentencepiece.bpe.model not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmphme0oya3
# Downloading:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# storing https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/sentencepiece.bpe.model in cache at /root/.cache/huggingface/transformers/e70140c9e0682f255072dc32b137ae3cde1808241a5359b356fa10413d32a677.71e50b08dbe7e5375398e165096cacc3d2086119d6a449364490da6908de655e
# creating metadata file for /root/.cache/huggingface/transformers/e70140c9e0682f255072dc32b137ae3cde1808241a5359b356fa10413d32a677.71e50b08dbe7e5375398e165096cacc3d2086119d6a449364490da6908de655e
# https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmphbcv1uep
# Downloading:   0%|          | 0.00/8.66M [00:00<?, ?B/s]
# storing https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/tokenizer.json in cache at /root/.cache/huggingface/transformers/6aa7bc2ebebd8aec9f0d822224378677812644178ecff3c50ceddf15ed84427c.2dedbd3aa2bb53e8e26ed0125daf18f6d4aeeeeb98252d7ce59b3a63d810a963
# creating metadata file for /root/.cache/huggingface/transformers/6aa7bc2ebebd8aec9f0d822224378677812644178ecff3c50ceddf15ed84427c.2dedbd3aa2bb53e8e26ed0125daf18f6d4aeeeeb98252d7ce59b3a63d810a963
# https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpml5u3ag8
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# storing https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/special_tokens_map.json in cache at /root/.cache/huggingface/transformers/f06ef5b71fd7eb7e035d0f645a260e1b7933933ff5438715bc96d41446ac6db1.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# creating metadata file for /root/.cache/huggingface/transformers/f06ef5b71fd7eb7e035d0f645a260e1b7933933ff5438715bc96d41446ac6db1.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# loading file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/sentencepiece.bpe.model from cache at /root/.cache/huggingface/transformers/e70140c9e0682f255072dc32b137ae3cde1808241a5359b356fa10413d32a677.71e50b08dbe7e5375398e165096cacc3d2086119d6a449364490da6908de655e
# loading file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/6aa7bc2ebebd8aec9f0d822224378677812644178ecff3c50ceddf15ed84427c.2dedbd3aa2bb53e8e26ed0125daf18f6d4aeeeeb98252d7ce59b3a63d810a963
# loading file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/f06ef5b71fd7eb7e035d0f645a260e1b7933933ff5438715bc96d41446ac6db1.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# loading file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-es/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/111d92253a878f3919c5c83c05be6fe131f4d4e29e27d3994266b0581067ef7a.b36482fbec4a714d3cfec99e0b05f4fdeec9e759090a78aed5597583a8b4783d
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
split = "test"
map_datasets(langs, split, prepare_validation_features)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
results_translate_train_es_xlm_r = compute_results(langs, split)
print(results_translate_train_es_xlm_r)
# Out:
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 448
#   Batch size = 16
#     <div>
#
#       <progress value='335' max='28' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [28/28 02:06]
#     </div>
# Post-processing 440 example predictions split into 448 features.
#   0%|          | 0/440 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 968
#   Batch size = 16
# Post-processing 921 example predictions split into 968 features.
#   0%|          | 0/921 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 127
#   Batch size = 16
# Post-processing 113 example predictions split into 127 features.
#   0%|          | 0/113 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 802
#   Batch size = 16
# Post-processing 782 example predictions split into 802 features.
#   0%|          | 0/782 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 577
#   Batch size = 16
# Post-processing 565 example predictions split into 577 features.
#   0%|          | 0/565 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 294
#   Batch size = 16
# Post-processing 276 example predictions split into 294 features.
#   0%|          | 0/276 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 862
#   Batch size = 16
# Post-processing 812 example predictions split into 862 features.
#   0%|          | 0/812 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 501
#   Batch size = 16
# Post-processing 499 example predictions split into 501 features.
#   0%|          | 0/499 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 715
#   Batch size = 16
# Post-processing 669 example predictions split into 715 features.
#   0%|          | 0/669 [00:00<?, ?it/s]
# {'en': {'exact_match': 59.09090909090909, 'f1': 71.79749243292903}, 'ar': {'exact_match': 52.11726384364821, 'f1': 68.2392121792472}, 'bn': {'exact_match': 44.24778761061947, 'f1': 63.56823609035997}, 'fi': {'exact_match': 56.265984654731454, 'f1': 71.17806303567654}, 'id': {'exact_match': 57.34513274336283, 'f1': 73.0660064915935}, 'ko': {'exact_match': 40.57971014492754, 'f1': 53.824908065673014}, 'ru': {'exact_match': 43.59605911330049, 'f1': 67.18369148756481}, 'sw': {'exact_match': 55.91182364729459, 'f1': 67.15128879031315}, 'te': {'exact_match': 54.40956651718984, 'f1': 71.71630859444106}}

# %%
df_results_translate_train_es_xlm_r = results_df(results_translate_train_es_xlm_r, "Translate-train es XLM-R")
df_results_translate_train_es_xlm_r.to_csv("results/tydiqa/results_translate_train_es_xlm_r.csv")
df_results_translate_train_es_xlm_r
# Out:
#   lang  F1_Translate-train es XLM-R  EM_Translate-train es XLM-R
# 0   en                        71.80                        59.09
# 1   ar                        68.24                        52.12
# 2   bn                        63.57                        44.25
# 3   fi                        71.18                        56.27
# 4   id                        73.07                        57.35
# 5   ko                        53.82                        40.58
# 6   ru                        67.18                        43.60
# 7   sw                        67.15                        55.91
# 8   te                        71.72                        54.41
# 9  avg                        67.53                        51.51

# %% [markdown]
# ## Translate Train De XLM-R

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "saattrupdan/xlmr-base-texas-squad-de"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="bert-multi-cased-finetuned-tydiqav1-de",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmphao37p2p
# Downloading:   0%|          | 0.00/716 [00:00<?, ?B/s]
# storing https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/cdb5bec2a4313b508170a5662b228920126f9cc3f6457d6af682d5e59bb0eddb.b749a309a5febb0957ff5acc5d4f5534d14f38569553b954c37647de7ea10ae4
# creating metadata file for /root/.cache/huggingface/transformers/cdb5bec2a4313b508170a5662b228920126f9cc3f6457d6af682d5e59bb0eddb.b749a309a5febb0957ff5acc5d4f5534d14f38569553b954c37647de7ea10ae4
# loading configuration file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/cdb5bec2a4313b508170a5662b228920126f9cc3f6457d6af682d5e59bb0eddb.b749a309a5febb0957ff5acc5d4f5534d14f38569553b954c37647de7ea10ae4
# Model config XLMRobertaConfig {
#   "_name_or_path": "saattrupdan/xlmr-base-texas-squad-de",
#   "architectures": [
#     "XLMRobertaForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "xlm-roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "torch_dtype": "float32",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 250002
# }
#
# https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpj41sjwda
# Downloading:   0%|          | 0.00/1.03G [00:00<?, ?B/s]
# storing https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/baae26a4312c9f8a60467d169c86f074b12b502f71e120116fd43127d8fec369.ac5c70422646da3639a67f8f3b4397655c52f38f40b877bdd5346bf8a262ec5b
# creating metadata file for /root/.cache/huggingface/transformers/baae26a4312c9f8a60467d169c86f074b12b502f71e120116fd43127d8fec369.ac5c70422646da3639a67f8f3b4397655c52f38f40b877bdd5346bf8a262ec5b
# loading weights file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/baae26a4312c9f8a60467d169c86f074b12b502f71e120116fd43127d8fec369.ac5c70422646da3639a67f8f3b4397655c52f38f40b877bdd5346bf8a262ec5b
# All model checkpoint weights were used when initializing XLMRobertaForQuestionAnswering.
#
# All the weights of XLMRobertaForQuestionAnswering were initialized from the model checkpoint at saattrupdan/xlmr-base-texas-squad-de.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use XLMRobertaForQuestionAnswering for predictions without further training.
# https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp0wbvaofj
# Downloading:   0%|          | 0.00/398 [00:00<?, ?B/s]
# storing https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/68ea7cef479e473feff43d31251891a998199eca701b9ced245da031208cc2ec.b36482fbec4a714d3cfec99e0b05f4fdeec9e759090a78aed5597583a8b4783d
# creating metadata file for /root/.cache/huggingface/transformers/68ea7cef479e473feff43d31251891a998199eca701b9ced245da031208cc2ec.b36482fbec4a714d3cfec99e0b05f4fdeec9e759090a78aed5597583a8b4783d
# https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/sentencepiece.bpe.model not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpasrsuohx
# Downloading:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# storing https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/sentencepiece.bpe.model in cache at /root/.cache/huggingface/transformers/dcd9c7533e4dc923a7d93332160caa103a15e8252a280e595187936107890a3d.71e50b08dbe7e5375398e165096cacc3d2086119d6a449364490da6908de655e
# creating metadata file for /root/.cache/huggingface/transformers/dcd9c7533e4dc923a7d93332160caa103a15e8252a280e595187936107890a3d.71e50b08dbe7e5375398e165096cacc3d2086119d6a449364490da6908de655e
# https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpw5e2_614
# Downloading:   0%|          | 0.00/8.66M [00:00<?, ?B/s]
# storing https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/tokenizer.json in cache at /root/.cache/huggingface/transformers/58413b3e02df0e3b7a5ad25e9b7a0709c6067918a79f56ef38091a009d12ed80.2dedbd3aa2bb53e8e26ed0125daf18f6d4aeeeeb98252d7ce59b3a63d810a963
# creating metadata file for /root/.cache/huggingface/transformers/58413b3e02df0e3b7a5ad25e9b7a0709c6067918a79f56ef38091a009d12ed80.2dedbd3aa2bb53e8e26ed0125daf18f6d4aeeeeb98252d7ce59b3a63d810a963
# https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpa5f7t3uu
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# storing https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/special_tokens_map.json in cache at /root/.cache/huggingface/transformers/1c41f702027728edbb98fd0333da299d53c23aad63c4e224e11c7d05473bcafe.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# creating metadata file for /root/.cache/huggingface/transformers/1c41f702027728edbb98fd0333da299d53c23aad63c4e224e11c7d05473bcafe.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# loading file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/sentencepiece.bpe.model from cache at /root/.cache/huggingface/transformers/dcd9c7533e4dc923a7d93332160caa103a15e8252a280e595187936107890a3d.71e50b08dbe7e5375398e165096cacc3d2086119d6a449364490da6908de655e
# loading file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/58413b3e02df0e3b7a5ad25e9b7a0709c6067918a79f56ef38091a009d12ed80.2dedbd3aa2bb53e8e26ed0125daf18f6d4aeeeeb98252d7ce59b3a63d810a963
# loading file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/1c41f702027728edbb98fd0333da299d53c23aad63c4e224e11c7d05473bcafe.a11ebb04664c067c8fe5ef8f8068b0f721263414a26058692f7b2e4ba2a1b342
# loading file https://huggingface.co/saattrupdan/xlmr-base-texas-squad-de/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/68ea7cef479e473feff43d31251891a998199eca701b9ced245da031208cc2ec.b36482fbec4a714d3cfec99e0b05f4fdeec9e759090a78aed5597583a8b4783d
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
split = "test"
map_datasets(langs, split, prepare_validation_features)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
results_translate_train_de_xlm_r = compute_results(langs, split)
print(results_translate_train_de_xlm_r)
# Out:
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 448
#   Batch size = 16
#     <div>
#
#       <progress value='335' max='28' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [28/28 02:12]
#     </div>
# Post-processing 440 example predictions split into 448 features.
#   0%|          | 0/440 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 968
#   Batch size = 16
# Post-processing 921 example predictions split into 968 features.
#   0%|          | 0/921 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 127
#   Batch size = 16
# Post-processing 113 example predictions split into 127 features.
#   0%|          | 0/113 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 802
#   Batch size = 16
# Post-processing 782 example predictions split into 802 features.
#   0%|          | 0/782 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 577
#   Batch size = 16
# Post-processing 565 example predictions split into 577 features.
#   0%|          | 0/565 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 294
#   Batch size = 16
# Post-processing 276 example predictions split into 294 features.
#   0%|          | 0/276 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 862
#   Batch size = 16
# Post-processing 812 example predictions split into 862 features.
#   0%|          | 0/812 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 501
#   Batch size = 16
# Post-processing 499 example predictions split into 501 features.
#   0%|          | 0/499 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `XLMRobertaForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `XLMRobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 715
#   Batch size = 16
# Post-processing 669 example predictions split into 715 features.
#   0%|          | 0/669 [00:00<?, ?it/s]
# {'en': {'exact_match': 63.18181818181818, 'f1': 73.62308719631477}, 'ar': {'exact_match': 50.1628664495114, 'f1': 65.99161783384383}, 'bn': {'exact_match': 49.557522123893804, 'f1': 64.71095276405009}, 'fi': {'exact_match': 60.10230179028133, 'f1': 72.39212468314446}, 'id': {'exact_match': 60.176991150442475, 'f1': 72.37962963130673}, 'ko': {'exact_match': 44.927536231884055, 'f1': 58.14896773246689}, 'ru': {'exact_match': 51.600985221674875, 'f1': 68.17565443906615}, 'sw': {'exact_match': 63.52705410821643, 'f1': 72.10676975826644}, 'te': {'exact_match': 53.81165919282511, 'f1': 72.81185640992113}}

# %%
df_results_translate_train_de_xlm_r = results_df(results_translate_train_de_xlm_r, "Translate-train de XLM-R")
df_results_translate_train_de_xlm_r.to_csv("results/tydiqa/results_translate_train_de_xlm_r.csv")
df_results_translate_train_de_xlm_r
# Out:
#   lang  F1_Translate-train de XLM-R  EM_Translate-train de XLM-R
# 0   en                        73.62                        63.18
# 1   ar                        65.99                        50.16
# 2   bn                        64.71                        49.56
# 3   fi                        72.39                        60.10
# 4   id                        72.38                        60.18
# 5   ko                        58.15                        44.93
# 6   ru                        68.18                        51.60
# 7   sw                        72.11                        63.53
# 8   te                        72.81                        53.81
# 9  avg                        68.93                        55.23

# %% [markdown]
# ## Translate Train All mBERT
#
# We also experiment with a multi-task version of the translate-train setting where we fine-tune mBERT on the combined translated training data of all languages jointly.

# %%
from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer

model_name = "bert-base-multilingual-cased"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

batch_size = 16

training_args = TrainingArguments(
    output_dir="bert-base-multilingual-cased-squad-all",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
    push_to_hub=True
)

# %%
langs = ["ar", "de", "zh", "vi", "es", "hi", "el", "th", "tr", "ru"]

split = "translate_train"
map_datasets(langs, split, prepare_train_features)

split = "translate_dev"
map_datasets(langs, split, prepare_train_features)

# %%
from datasets import DatasetDict, concatenate_datasets

tydiqa_merged = DatasetDict()
tydiqa_merged["translate_train"] = squad_train["train"]
tydiqa_merged["translate_dev"] = squad_train["validation"]

for lang in langs:
    for split in ["translate_train", "translate_dev"]:
        tydiqa_merged[split] = concatenate_datasets([tydiqa_merged[split], tydiqa_prep[lang][split]])

# %%
tydiqa_merged

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tydiqa_merged["translate_train"],
    eval_dataset=tydiqa_merged["translate_dev"],
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# %%
# trainer.train()

# %%
langs = ["ar", "de", "zh", "vi", "en", "es", "hi", "el", "th", "tr", "ru", "ro"]
split = "test"

map_datasets(langs, split, prepare_validation_features)

# %%
langs = ["ar", "de", "zh", "vi", "en", "es", "hi", "el", "th", "tr", "ru", "ro"]
split = "test"
results_translate_train_all_mbert = compute_results(langs, split)
print(results_translate_train_all_mbert)

# %%
df_results_translate_train_all_mbert = results_df(results_translate_train_all_mbert, "TTr_all_mbert")
df_results_translate_train_all_mbert.to_csv("results/tydiqa/results_translate_train_all_mbert.csv")
df_results_translate_train_all_mbert

# %%
trainer.push_to_hub()

# %% [markdown]
# ## Fine-tuning mBERT

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="distilbert-multi-finetuned-for-xqua-on-tydiqa",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpixedcuer
# Downloading:   0%|          | 0.00/475 [00:00<?, ?B/s]
# storing https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/04ede374888902aea9e5272b6bccd0b2543fbfa4842d59e10e76753a7600abc6.f94085766043a5d726b68a8cbd03a8e321c1cce2ba02f3a34fc39cc2bcad3de9
# creating metadata file for /root/.cache/huggingface/transformers/04ede374888902aea9e5272b6bccd0b2543fbfa4842d59e10e76753a7600abc6.f94085766043a5d726b68a8cbd03a8e321c1cce2ba02f3a34fc39cc2bcad3de9
# loading configuration file https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/04ede374888902aea9e5272b6bccd0b2543fbfa4842d59e10e76753a7600abc6.f94085766043a5d726b68a8cbd03a8e321c1cce2ba02f3a34fc39cc2bcad3de9
# Model config DistilBertConfig {
#   "_name_or_path": "mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForQuestionAnswering"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.19.2",
#   "vocab_size": 119547
# }
#
# https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpfyd51cmn
# Downloading:   0%|          | 0.00/514M [00:00<?, ?B/s]
# storing https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/9b044ccca92fa64b21f5f6b0fef67176d194808054e0c5179fd93fc1b67fb69e.b2bf6026305896fccf65004de1e246af5a7b68b786333704180c050470450aeb
# creating metadata file for /root/.cache/huggingface/transformers/9b044ccca92fa64b21f5f6b0fef67176d194808054e0c5179fd93fc1b67fb69e.b2bf6026305896fccf65004de1e246af5a7b68b786333704180c050470450aeb
# loading weights file https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/9b044ccca92fa64b21f5f6b0fef67176d194808054e0c5179fd93fc1b67fb69e.b2bf6026305896fccf65004de1e246af5a7b68b786333704180c050470450aeb
# All model checkpoint weights were used when initializing DistilBertForQuestionAnswering.
#
# All the weights of DistilBertForQuestionAnswering were initialized from the model checkpoint at mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use DistilBertForQuestionAnswering for predictions without further training.
# https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpko3z769k
# Downloading:   0%|          | 0.00/40.0 [00:00<?, ?B/s]
# storing https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/ccf3198b32e4ac928c3b94cc94c3b910b4c0035c3eeaac0ee12a8001970ecafb.f19de0c372e9b00104464e8b09d5fbbdd67565d0e0af78462fb22d8f5d2c1fe1
# creating metadata file for /root/.cache/huggingface/transformers/ccf3198b32e4ac928c3b94cc94c3b910b4c0035c3eeaac0ee12a8001970ecafb.f19de0c372e9b00104464e8b09d5fbbdd67565d0e0af78462fb22d8f5d2c1fe1
# loading configuration file https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/04ede374888902aea9e5272b6bccd0b2543fbfa4842d59e10e76753a7600abc6.f94085766043a5d726b68a8cbd03a8e321c1cce2ba02f3a34fc39cc2bcad3de9
# Model config DistilBertConfig {
#   "_name_or_path": "mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForQuestionAnswering"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.19.2",
#   "vocab_size": 119547
# }
#
# https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpq_u8_tyl
# Downloading:   0%|          | 0.00/972k [00:00<?, ?B/s]
# storing https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/vocab.txt in cache at /root/.cache/huggingface/transformers/e8b6a8f34ec4accdfdb5969eee166c473de73e9047707db3d04fcb375588db5c.6c5b6600e968f4b5e08c86d8891ea99e51537fc2bf251435fb46922e8f7a7b29
# creating metadata file for /root/.cache/huggingface/transformers/e8b6a8f34ec4accdfdb5969eee166c473de73e9047707db3d04fcb375588db5c.6c5b6600e968f4b5e08c86d8891ea99e51537fc2bf251435fb46922e8f7a7b29
# https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpxoxtlm7n
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# storing https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/special_tokens_map.json in cache at /root/.cache/huggingface/transformers/7b639db866b5b3289daef1432531bf4e1d0b8e9006c4bfce223ddf84818e8f64.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# creating metadata file for /root/.cache/huggingface/transformers/7b639db866b5b3289daef1432531bf4e1d0b8e9006c4bfce223ddf84818e8f64.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# loading file https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/e8b6a8f34ec4accdfdb5969eee166c473de73e9047707db3d04fcb375588db5c.6c5b6600e968f4b5e08c86d8891ea99e51537fc2bf251435fb46922e8f7a7b29
# loading file https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/7b639db866b5b3289daef1432531bf4e1d0b8e9006c4bfce223ddf84818e8f64.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# loading file https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/ccf3198b32e4ac928c3b94cc94c3b910b4c0035c3eeaac0ee12a8001970ecafb.f19de0c372e9b00104464e8b09d5fbbdd67565d0e0af78462fb22d8f5d2c1fe1
# loading configuration file https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/04ede374888902aea9e5272b6bccd0b2543fbfa4842d59e10e76753a7600abc6.f94085766043a5d726b68a8cbd03a8e321c1cce2ba02f3a34fc39cc2bcad3de9
# Model config DistilBertConfig {
#   "_name_or_path": "mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForQuestionAnswering"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.19.2",
#   "vocab_size": 119547
# }
#
# loading configuration file https://huggingface.co/mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/04ede374888902aea9e5272b6bccd0b2543fbfa4842d59e10e76753a7600abc6.f94085766043a5d726b68a8cbd03a8e321c1cce2ba02f3a34fc39cc2bcad3de9
# Model config DistilBertConfig {
#   "_name_or_path": "mrm8488/distilbert-multi-finetuned-for-xqua-on-tydiqa",
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForQuestionAnswering"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "output_past": true,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.19.2",
#   "vocab_size": 119547
# }
#
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
split = "test"
map_datasets(langs, split, prepare_validation_features)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
results_fine_tuning_tydiqa_mbert = compute_results(langs, split)
print(results_fine_tuning_tydiqa_mbert)
# Out:
# The following columns in the test set don't have a corresponding argument in `DistilBertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `DistilBertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 447
#   Batch size = 16
#     <div>
#
#       <progress value='344' max='28' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [28/28 01:13]
#     </div>
# Post-processing 440 example predictions split into 447 features.
#   0%|          | 0/440 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `DistilBertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `DistilBertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 998
#   Batch size = 16
# Post-processing 921 example predictions split into 998 features.
#   0%|          | 0/921 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `DistilBertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `DistilBertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 140
#   Batch size = 16
# Post-processing 113 example predictions split into 140 features.
#   0%|          | 0/113 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `DistilBertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `DistilBertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 810
#   Batch size = 16
# Post-processing 782 example predictions split into 810 features.
#   0%|          | 0/782 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `DistilBertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `DistilBertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 580
#   Batch size = 16
# Post-processing 565 example predictions split into 580 features.
#   0%|          | 0/565 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `DistilBertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `DistilBertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 298
#   Batch size = 16
# Post-processing 276 example predictions split into 298 features.
#   0%|          | 0/276 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `DistilBertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `DistilBertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 884
#   Batch size = 16
# Post-processing 812 example predictions split into 884 features.
#   0%|          | 0/812 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `DistilBertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `DistilBertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 503
#   Batch size = 16
# Post-processing 499 example predictions split into 503 features.
#   0%|          | 0/499 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `DistilBertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `DistilBertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 776
#   Batch size = 16
# Post-processing 669 example predictions split into 776 features.
#   0%|          | 0/669 [00:00<?, ?it/s]
# {'en': {'exact_match': 63.40909090909091, 'f1': 74.6550467471178}, 'ar': {'exact_match': 68.07817589576547, 'f1': 81.28932531917248}, 'bn': {'exact_match': 53.982300884955755, 'f1': 65.26684230224053}, 'fi': {'exact_match': 69.18158567774935, 'f1': 79.58361205878722}, 'id': {'exact_match': 70.4424778761062, 'f1': 81.91381226042586}, 'ko': {'exact_match': 52.89855072463768, 'f1': 63.00815431996572}, 'ru': {'exact_match': 60.83743842364532, 'f1': 71.15745942179265}, 'sw': {'exact_match': 75.1503006012024, 'f1': 81.50080306614916}, 'te': {'exact_match': 66.81614349775785, 'f1': 80.44646102942066}}

# %%
df_results_fine_tuning_tydiqa_mbert = results_df(results_fine_tuning_tydiqa_mbert, "Fine-tuning mBERT")
df_results_fine_tuning_tydiqa_mbert.to_csv("results/tydiqa/results_fine_tuning_mbert.csv")
df_results_fine_tuning_tydiqa_mbert
# Out:
#   lang  F1_Fine-tuning mBERT  EM_Fine-tuning mBERT
# 0   en                 74.66                 63.41
# 1   ar                 81.29                 68.08
# 2   bn                 65.27                 53.98
# 3   fi                 79.58                 69.18
# 4   id                 81.91                 70.44
# 5   ko                 63.01                 52.90
# 6   ru                 71.16                 60.84
# 7   sw                 81.50                 75.15
# 8   te                 80.45                 66.82
# 9  avg                 75.42                 64.53

# %% [markdown]
# ## Data Augmentation mBERT

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, TrainingArguments, Trainer, DefaultDataCollator

model_name = "mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
data_collator = DefaultDataCollator()

batch_size = 16
training_args = TrainingArguments(
    output_dir="bert-multi-cased-finetuned-tydiqav1",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=None,
    eval_dataset=None,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp1dax2870
# Downloading:   0%|          | 0.00/657 [00:00<?, ?B/s]
# storing https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/66a1a2fcf63972a264c297e96b41c58d31fa6cfc46fb3d9f266fc0bbadc297e9.b94e26d9c4c6febfe5881b469240758616a103ec32f181f3bec6660712555f9b
# creating metadata file for /root/.cache/huggingface/transformers/66a1a2fcf63972a264c297e96b41c58d31fa6cfc46fb3d9f266fc0bbadc297e9.b94e26d9c4c6febfe5881b469240758616a103ec32f181f3bec6660712555f9b
# loading configuration file https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/66a1a2fcf63972a264c297e96b41c58d31fa6cfc46fb3d9f266fc0bbadc297e9.b94e26d9c4c6febfe5881b469240758616a103ec32f181f3bec6660712555f9b
# Model config BertConfig {
#   "_name_or_path": "mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 119547
# }
#
# https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpb0y0zs4f
# Downloading:   0%|          | 0.00/679M [00:00<?, ?B/s]
# storing https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/b4f01d30e396164cd666137ae73c9c0bdd8efc24e3d3f1848ef1feb16d1da406.7f28f06c145df4bf7b5b80325cbc44a294440a61166daab86a2eaac87dfc227a
# creating metadata file for /root/.cache/huggingface/transformers/b4f01d30e396164cd666137ae73c9c0bdd8efc24e3d3f1848ef1feb16d1da406.7f28f06c145df4bf7b5b80325cbc44a294440a61166daab86a2eaac87dfc227a
# loading weights file https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/b4f01d30e396164cd666137ae73c9c0bdd8efc24e3d3f1848ef1feb16d1da406.7f28f06c145df4bf7b5b80325cbc44a294440a61166daab86a2eaac87dfc227a
# All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# All the weights of BertForQuestionAnswering were initialized from the model checkpoint at mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp9ag62ua4
# Downloading:   0%|          | 0.00/152 [00:00<?, ?B/s]
# storing https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/9bf945a50ba5f04e49a9b599037071acd150812ae971444f7f508e799af8ba8c.3e813ef7b46a58d7e35c90b0aacc2127a3800bba6bff791af1651012cf2fab11
# creating metadata file for /root/.cache/huggingface/transformers/9bf945a50ba5f04e49a9b599037071acd150812ae971444f7f508e799af8ba8c.3e813ef7b46a58d7e35c90b0aacc2127a3800bba6bff791af1651012cf2fab11
# loading configuration file https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/66a1a2fcf63972a264c297e96b41c58d31fa6cfc46fb3d9f266fc0bbadc297e9.b94e26d9c4c6febfe5881b469240758616a103ec32f181f3bec6660712555f9b
# Model config BertConfig {
#   "_name_or_path": "mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 119547
# }
#
# https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmphnzawsnp
# Downloading:   0%|          | 0.00/972k [00:00<?, ?B/s]
# storing https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/vocab.txt in cache at /root/.cache/huggingface/transformers/6ea3c660695d3ae107ec7bcf05dd06940fc642773e8c8c2f85e952064f42c127.6c5b6600e968f4b5e08c86d8891ea99e51537fc2bf251435fb46922e8f7a7b29
# creating metadata file for /root/.cache/huggingface/transformers/6ea3c660695d3ae107ec7bcf05dd06940fc642773e8c8c2f85e952064f42c127.6c5b6600e968f4b5e08c86d8891ea99e51537fc2bf251435fb46922e8f7a7b29
# https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp_5stzyr_
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# storing https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/special_tokens_map.json in cache at /root/.cache/huggingface/transformers/e0c8fa9208ce0a8ea5e0df356afec8a97e65a2230299501022a24f0b8e99c517.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# creating metadata file for /root/.cache/huggingface/transformers/e0c8fa9208ce0a8ea5e0df356afec8a97e65a2230299501022a24f0b8e99c517.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# loading file https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/6ea3c660695d3ae107ec7bcf05dd06940fc642773e8c8c2f85e952064f42c127.6c5b6600e968f4b5e08c86d8891ea99e51537fc2bf251435fb46922e8f7a7b29
# loading file https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/tokenizer.json from cache at None
# loading file https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/e0c8fa9208ce0a8ea5e0df356afec8a97e65a2230299501022a24f0b8e99c517.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# loading file https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/9bf945a50ba5f04e49a9b599037071acd150812ae971444f7f508e799af8ba8c.3e813ef7b46a58d7e35c90b0aacc2127a3800bba6bff791af1651012cf2fab11
# loading configuration file https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/66a1a2fcf63972a264c297e96b41c58d31fa6cfc46fb3d9f266fc0bbadc297e9.b94e26d9c4c6febfe5881b469240758616a103ec32f181f3bec6660712555f9b
# Model config BertConfig {
#   "_name_or_path": "mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 119547
# }
#
# loading configuration file https://huggingface.co/mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/66a1a2fcf63972a264c297e96b41c58d31fa6cfc46fb3d9f266fc0bbadc297e9.b94e26d9c4c6febfe5881b469240758616a103ec32f181f3bec6660712555f9b
# Model config BertConfig {
#   "_name_or_path": "mrm8488/bert-multi-cased-finedtuned-xquad-tydiqa-goldp",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "directionality": "bidi",
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.19.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 119547
# }
#
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
split = "test"
map_datasets(langs, split, prepare_validation_features)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
results_data_augmentation_mbert = compute_results(langs, split)
print(results_data_augmentation_mbert)
# Out:
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 447
#   Batch size = 16
#     <div>
#
#       <progress value='344' max='28' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [28/28 02:20]
#     </div>
# Post-processing 440 example predictions split into 447 features.
#   0%|          | 0/440 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 998
#   Batch size = 16
# Post-processing 921 example predictions split into 998 features.
#   0%|          | 0/921 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 140
#   Batch size = 16
# Post-processing 113 example predictions split into 140 features.
#   0%|          | 0/113 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 810
#   Batch size = 16
# Post-processing 782 example predictions split into 810 features.
#   0%|          | 0/782 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 580
#   Batch size = 16
# Post-processing 565 example predictions split into 580 features.
#   0%|          | 0/565 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 298
#   Batch size = 16
# Post-processing 276 example predictions split into 298 features.
#   0%|          | 0/276 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 884
#   Batch size = 16
# Post-processing 812 example predictions split into 884 features.
#   0%|          | 0/812 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 503
#   Batch size = 16
# Post-processing 499 example predictions split into 503 features.
#   0%|          | 0/499 [00:00<?, ?it/s]
# The following columns in the test set don't have a corresponding argument in `BertForQuestionAnswering.forward` and have been ignored: offset_mapping, example_id. If offset_mapping, example_id are not expected by `BertForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 776
#   Batch size = 16
# Post-processing 669 example predictions split into 776 features.
#   0%|          | 0/669 [00:00<?, ?it/s]
# {'en': {'exact_match': 74.0909090909091, 'f1': 84.2085362056512}, 'ar': {'exact_match': 74.7014115092291, 'f1': 86.3608415557019}, 'bn': {'exact_match': 65.48672566371681, 'f1': 77.64522596381005}, 'fi': {'exact_match': 74.16879795396419, 'f1': 84.161172440082}, 'id': {'exact_match': 80.17699115044248, 'f1': 88.51622653914282}, 'ko': {'exact_match': 67.3913043478261, 'f1': 75.19801716871663}, 'ru': {'exact_match': 70.07389162561576, 'f1': 81.02311416613163}, 'sw': {'exact_match': 79.75951903807615, 'f1': 85.51055346546308}, 'te': {'exact_match': 71.59940209267563, 'f1': 84.75346692835483}}

# %%
df_results_data_augmentation_mbert = results_df(results_data_augmentation_mbert, "Data-augmentation mBERT")
df_results_data_augmentation_mbert.to_csv("results/tydiqa/results_data_augmentation_mbert.csv")
df_results_data_augmentation_mbert
# Out:
#   lang  F1_Data-augmentation mBERT  EM_Data-augmentation mBERT
# 0   en                       84.21                       74.09
# 1   ar                       86.36                       74.70
# 2   bn                       77.65                       65.49
# 3   fi                       84.16                       74.17
# 4   id                       88.52                       80.18
# 5   ko                       75.20                       67.39
# 6   ru                       81.02                       70.07
# 7   sw                       85.51                       79.76
# 8   te                       84.75                       71.60
# 9  avg                       83.04                       73.05

# %% [markdown]
# ## Baselines

# %% [markdown]
# ## Results
#
# |                              | en          | ar          | bn          | fi          | id          | ko          | ru          | sw          | te          | avg         |
# |:-----------------------------|:------------|:------------|:------------|:------------|:------------|:------------|:------------|:------------|:------------|:------------|
# | Zero-shot mBERT              | 77.8 / 69.8 | 60.6 / 45.1 | 59.5 / 47.8 | 60.6 / 50.1 | 63.0 / 50.6 | 47.9 / 39.5 | 65.3 / 47.3 | 61.0 / 49.5 | 48.9 / 41.4 | 60.5 / 49.0 |
# | Zero-shot XLM-R              | 75.2 / 65.9 | 66.7 / 52.8 | 67.5 / 51.3 | 72.6 / 62.3 | 75.8 / 61.6 | 62.6 / 53.6 | 67.6 / 48.9 | 68.8 / 59.1 | 74.6 / 58.6 | 70.2 / 57.1 |
# | Zero-shot XLM-R Large        | 81.4 / 70.9 | 78.2 / 64.1 | 75.3 / 60.2 | 79.8 / 68.5 | 81.7 / 68.7 | 72.9 / 62.0 | 73.1 / 52.6 | 81.6 / 71.9 | 80.8 / 67.1 | 78.3 / 65.1 |
# | Translate-test BERT          | nan         | 67.2 / 49.8 | 76.6 / 64.1 | 71.2 / 57.5 | 74.2 / 60.3 | 70.1 / 58.9 | 71.9 / 55.5 | 76.0 / 63.8 | 63.5 / 51.1 | 71.3 / 57.6 |
# | Translate-test BERT Large    | nan         | 69.8 / 52.2 | 79.0 / 64.1 | 76.8 / 64.2 | 76.0 / 62.4 | 73.8 / 63.5 | 75.3 / 60.1 | 80.9 / 69.8 | 79.7 / 66.2 | 76.4 / 62.8 |
# | Translate-test RoBERTa       | nan         | 66.9 / 47.6 | 72.4 / 57.5 | 74.3 / 60.4 | 74.4 / 60.9 | 70.3 / 57.4 | 71.6 / 55.1 | 78.6 / 67.0 | 69.2 / 55.5 | 72.2 / 57.7 |
# | Translate-test RoBERTa Large | nan         | 66.9 / 48.1 | 78.1 / 63.0 | 75.4 / 60.6 | 73.0 / 56.8 | 73.2 / 61.6 | 74.3 / 58.1 | 80.2 / 69.6 | 78.0 / 63.2 | 74.9 / 60.1 |
# | Translate-test mBERT         | nan         | 66.7 / 48.9 | 70.4 / 56.4 | 73.2 / 61.6 | 72.9 / 59.1 | 71.9 / 60.3 | 72.0 / 55.5 | 79.8 / 68.4 | 66.9 / 55.0 | 71.7 / 58.2 |
# | Translate-test XLM-R         | nan         | 63.6 / 46.4 | 72.4 / 60.8 | 69.6 / 56.9 | 71.2 / 58.3 | 69.6 / 56.2 | 70.8 / 55.1 | 78.8 / 68.9 | 59.4 / 46.8 | 69.4 / 56.2 |
# | Translate-test XLM-R Large   | nan         | 68.6 / 52.5 | 73.3 / 58.0 | 75.2 / 61.3 | 75.5 / 62.9 | 68.5 / 56.7 | 73.8 / 58.7 | 80.2 / 69.5 | 76.6 / 61.8 | 74.0 / 60.2 |
# | Translate-train es XLM-R     | 71.8 / 59.1 | 68.2 / 52.1 | 63.6 / 44.2 | 71.2 / 56.3 | 73.1 / 57.4 | 53.8 / 40.6 | 67.2 / 43.6 | 67.2 / 55.9 | 71.7 / 54.4 | 67.5 / 51.5 |
# | Translate-train de XLM-R     | 73.6 / 63.2 | 66.0 / 50.2 | 64.7 / 49.6 | 72.4 / 60.1 | 72.4 / 60.2 | 58.2 / 44.9 | 68.2 / 51.6 | 72.1 / 63.5 | 72.8 / 53.8 | 68.9 / 55.2 |
# | Fine-tuning mBERT            | 74.7 / 63.4 | 81.3 / 68.1 | 65.3 / 54.0 | 79.6 / 69.2 | 81.9 / 70.4 | 63.0 / 52.9 | 71.2 / 60.8 | 81.5 / 75.2 | 80.4 / 66.8 | 75.4 / 64.5 |
# | Data-augmentation mBERT      | 84.2 / 74.1 | 86.4 / 74.7 | 77.6 / 65.5 | 84.2 / 74.2 | 88.5 / 80.2 | 75.2 / 67.4 | 81.0 / 70.1 | 85.5 / 79.8 | 84.8 / 71.6 | 83.0 / 73.0 |

# %%
import pandas as pd

df_results_zero_shot_mbert = pd.read_csv('results/tydiqa/results_zero_shot_mbert.csv')
df_results_zero_shot_xlm_r = pd.read_csv('results/tydiqa/results_zero_shot_xlm_r.csv')
df_results_zero_shot_xlm_r_large = pd.read_csv("results/tydiqa/results_zero_shot_xlm_r_large.csv")
df_results_translate_test_mbert = pd.read_csv("results/tydiqa/results_translate_test_mbert.csv")
df_results_translate_test_bert = pd.read_csv("results/tydiqa/results_translate_test_bert.csv")
df_results_translate_test_bert_large = pd.read_csv("results/tydiqa/results_translate_test_bert_large.csv")
df_results_translate_test_xlm_r = pd.read_csv("results/tydiqa/results_translate_test_xlm_r.csv")
df_results_translate_test_xlm_r_large = pd.read_csv("results/tydiqa/results_translate_test_xlm_r_large.csv")
df_results_translate_test_roberta = pd.read_csv("results/tydiqa/results_translate_test_roberta.csv")
df_results_translate_test_roberta_large = pd.read_csv("results/tydiqa/results_translate_test_roberta_large.csv")
df_results_translate_train_es_xlm_r = pd.read_csv("results/tydiqa/results_translate_train_es_xlm_r.csv")
df_results_translate_train_de_xlm_r = pd.read_csv("results/tydiqa/results_translate_train_de_xlm_r.csv")
df_results_fine_tuning_mbert = pd.read_csv("results/tydiqa/results_fine_tuning_mbert.csv")
df_results_data_augmentation_mbert = pd.read_csv("results/tydiqa/results_data_augmentation_mbert.csv")


dataframes = [df_results_zero_shot_mbert, 
              df_results_zero_shot_xlm_r, 
              df_results_zero_shot_xlm_r_large, 
              df_results_translate_test_bert, 
              df_results_translate_test_bert_large, 
              df_results_translate_test_roberta, 
              df_results_translate_test_roberta_large, 
              df_results_translate_test_mbert, 
              df_results_translate_test_xlm_r, 
              df_results_translate_test_xlm_r_large, 
              df_results_translate_train_es_xlm_r, 
              df_results_translate_train_de_xlm_r,
              df_results_fine_tuning_mbert,
              df_results_data_augmentation_mbert, 
              ]

# %%
dfs = []
for df in dataframes:
    name1 = list(df.columns)[2]
    name2 = list(df.columns)[3]
    name = name1[3:]
    df = df.round(1)
    df = df.astype({name1: 'str', name2: 'str'}) #float to string
    df[name] = df[[name1, name2]].apply(lambda x: ' / '.join(x), axis=1) #concat F1 and EM
    df = df.drop([name1, name2,"Unnamed: 0"], axis=1) #remove useless columns
    df = df.set_index('lang').T #rotate dataframe
    dfs.append(df)

# %%
results_df = pd.concat(dfs, axis=0)
results_df.to_csv("results/tydiqa/results.csv")
display(results_df)
# Out:
# lang                                   en           ar           bn  \
# Zero-shot mBERT               77.8 / 69.8  60.6 / 45.1  59.5 / 47.8
# Zero-shot XLM-R               75.2 / 65.9  66.7 / 52.8  67.5 / 51.3
# Zero-shot XLM-R Large         81.4 / 70.9  78.2 / 64.1  75.3 / 60.2
# Translate-test BERT                   NaN  67.2 / 49.8  76.6 / 64.1
# Translate-test BERT Large             NaN  69.8 / 52.2  79.0 / 64.1
# Translate-test RoBERTa                NaN  66.9 / 47.6  72.4 / 57.5
# Translate-test RoBERTa Large          NaN  66.9 / 48.1  78.1 / 63.0
# Translate-test mBERT                  NaN  66.7 / 48.9  70.4 / 56.4
# Translate-test XLM-R                  NaN  63.6 / 46.4  72.4 / 60.8
# Translate-test XLM-R Large            NaN  68.6 / 52.5  73.3 / 58.0
# Translate-train es XLM-R      71.8 / 59.1  68.2 / 52.1  63.6 / 44.2
# Translate-train de XLM-R      73.6 / 63.2  66.0 / 50.2  64.7 / 49.6
# Fine-tuning mBERT             74.7 / 63.4  81.3 / 68.1  65.3 / 54.0
# Data-augmentation mBERT       84.2 / 74.1  86.4 / 74.7  77.6 / 65.5
#
# lang                                   fi           id           ko  \
# Zero-shot mBERT               60.6 / 50.1  63.0 / 50.6  47.9 / 39.5
# Zero-shot XLM-R               72.6 / 62.3  75.8 / 61.6  62.6 / 53.6
# Zero-shot XLM-R Large         79.8 / 68.5  81.7 / 68.7  72.9 / 62.0
# Translate-test BERT           71.2 / 57.5  74.2 / 60.3  70.1 / 58.9
# Translate-test BERT Large     76.8 / 64.2  76.0 / 62.4  73.8 / 63.5
# Translate-test RoBERTa        74.3 / 60.4  74.4 / 60.9  70.3 / 57.4
# Translate-test RoBERTa Large  75.4 / 60.6  73.0 / 56.8  73.2 / 61.6
# Translate-test mBERT          73.2 / 61.6  72.9 / 59.1  71.9 / 60.3
# Translate-test XLM-R          69.6 / 56.9  71.2 / 58.3  69.6 / 56.2
# Translate-test XLM-R Large    75.2 / 61.3  75.5 / 62.9  68.5 / 56.7
# Translate-train es XLM-R      71.2 / 56.3  73.1 / 57.4  53.8 / 40.6
# Translate-train de XLM-R      72.4 / 60.1  72.4 / 60.2  58.2 / 44.9
# Fine-tuning mBERT             79.6 / 69.2  81.9 / 70.4  63.0 / 52.9
# Data-augmentation mBERT       84.2 / 74.2  88.5 / 80.2  75.2 / 67.4
#
# lang                                   ru           sw           te  \
# Zero-shot mBERT               65.3 / 47.3  61.0 / 49.5  48.9 / 41.4
# Zero-shot XLM-R               67.6 / 48.9  68.8 / 59.1  74.6 / 58.6
# Zero-shot XLM-R Large         73.1 / 52.6  81.6 / 71.9  80.8 / 67.1
# Translate-test BERT           71.9 / 55.5  76.0 / 63.8  63.5 / 51.1
# Translate-test BERT Large     75.3 / 60.1  80.9 / 69.8  79.7 / 66.2
# Translate-test RoBERTa        71.6 / 55.1  78.6 / 67.0  69.2 / 55.5
# Translate-test RoBERTa Large  74.3 / 58.1  80.2 / 69.6  78.0 / 63.2
# Translate-test mBERT          72.0 / 55.5  79.8 / 68.4  66.9 / 55.0
# Translate-test XLM-R          70.8 / 55.1  78.8 / 68.9  59.4 / 46.8
# Translate-test XLM-R Large    73.8 / 58.7  80.2 / 69.5  76.6 / 61.8
# Translate-train es XLM-R      67.2 / 43.6  67.2 / 55.9  71.7 / 54.4
# Translate-train de XLM-R      68.2 / 51.6  72.1 / 63.5  72.8 / 53.8
# Fine-tuning mBERT             71.2 / 60.8  81.5 / 75.2  80.4 / 66.8
# Data-augmentation mBERT       81.0 / 70.1  85.5 / 79.8  84.8 / 71.6
#
# lang                                  avg
# Zero-shot mBERT               60.5 / 49.0
# Zero-shot XLM-R               70.2 / 57.1
# Zero-shot XLM-R Large         78.3 / 65.1
# Translate-test BERT           71.3 / 57.6
# Translate-test BERT Large     76.4 / 62.8
# Translate-test RoBERTa        72.2 / 57.7
# Translate-test RoBERTa Large  74.9 / 60.1
# Translate-test mBERT          71.7 / 58.2
# Translate-test XLM-R          69.4 / 56.2
# Translate-test XLM-R Large    74.0 / 60.2
# Translate-train es XLM-R      67.5 / 51.5
# Translate-train de XLM-R      68.9 / 55.2
# Fine-tuning mBERT             75.4 / 64.5
# Data-augmentation mBERT       83.0 / 73.0

# %%
results_df.to_markdown()
# Out:
# '|                              | en          | ar          | bn          | fi          | id          | ko          | ru          | sw          | te          | avg         |\n|:-----------------------------|:------------|:------------|:------------|:------------|:------------|:------------|:------------|:------------|:------------|:------------|\n| Zero-shot mBERT              | 77.8 / 69.8 | 60.6 / 45.1 | 59.5 / 47.8 | 60.6 / 50.1 | 63.0 / 50.6 | 47.9 / 39.5 | 65.3 / 47.3 | 61.0 / 49.5 | 48.9 / 41.4 | 60.5 / 49.0 |\n| Zero-shot XLM-R              | 75.2 / 65.9 | 66.7 / 52.8 | 67.5 / 51.3 | 72.6 / 62.3 | 75.8 / 61.6 | 62.6 / 53.6 | 67.6 / 48.9 | 68.8 / 59.1 | 74.6 / 58.6 | 70.2 / 57.1 |\n| Zero-shot XLM-R Large        | 81.4 / 70.9 | 78.2 / 64.1 | 75.3 / 60.2 | 79.8 / 68.5 | 81.7 / 68.7 | 72.9 / 62.0 | 73.1 / 52.6 | 81.6 / 71.9 | 80.8 / 67.1 | 78.3 / 65.1 |\n| Translate-test BERT          | nan         | 67.2 / 49.8 | 76.6 / 64.1 | 71.2 / 57.5 | 74.2 / 60.3 | 70.1 / 58.9 | 71.9 / 55.5 | 76.0 / 63.8 | 63.5 / 51.1 | 71.3 / 57.6 |\n| Translate-test BERT Large    | nan         | 69.8 / 52.2 | 79.0 / 64.1 | 76.8 / 64.2 | 76.0 / 62.4 | 73.8 / 63.5 | 75.3 / 60.1 | 80.9 / 69.8 | 79.7 / 66.2 | 76.4 / 62.8 |\n| Translate-test RoBERTa       | nan         | 66.9 / 47.6 | 72.4 / 57.5 | 74.3 / 60.4 | 74.4 / 60.9 | 70.3 / 57.4 | 71.6 / 55.1 | 78.6 / 67.0 | 69.2 / 55.5 | 72.2 / 57.7 |\n| Translate-test RoBERTa Large | nan         | 66.9 / 48.1 | 78.1 / 63.0 | 75.4 / 60.6 | 73.0 / 56.8 | 73.2 / 61.6 | 74.3 / 58.1 | 80.2 / 69.6 | 78.0 / 63.2 | 74.9 / 60.1 |\n| Translate-test mBERT         | nan         | 66.7 / 48.9 | 70.4 / 56.4 | 73.2 / 61.6 | 72.9 / 59.1 | 71.9 / 60.3 | 72.0 / 55.5 | 79.8 / 68.4 | 66.9 / 55.0 | 71.7 / 58.2 |\n| Translate-test XLM-R         | nan         | 63.6 / 46.4 | 72.4 / 60.8 | 69.6 / 56.9 | 71.2 / 58.3 | 69.6 / 56.2 | 70.8 / 55.1 | 78.8 / 68.9 | 59.4 / 46.8 | 69.4 / 56.2 |\n| Translate-test XLM-R Large   | nan         | 68.6 / 52.5 | 73.3 / 58.0 | 75.2 / 61.3 | 75.5 / 62.9 | 68.5 / 56.7 | 73.8 / 58.7 | 80.2 / 69.5 | 76.6 / 61.8 | 74.0 / 60.2 |\n| Translate-train es XLM-R     | 71.8 / 59.1 | 68.2 / 52.1 | 63.6 / 44.2 | 71.2 / 56.3 | 73.1 / 57.4 | 53.8 / 40.6 | 67.2 / 43.6 | 67.2 / 55.9 | 71.7 / 54.4 | 67.5 / 51.5 |\n| Translate-train de XLM-R     | 73.6 / 63.2 | 66.0 / 50.2 | 64.7 / 49.6 | 72.4 / 60.1 | 72.4 / 60.2 | 58.2 / 44.9 | 68.2 / 51.6 | 72.1 / 63.5 | 72.8 / 53.8 | 68.9 / 55.2 |\n| Fine-tuning mBERT            | 74.7 / 63.4 | 81.3 / 68.1 | 65.3 / 54.0 | 79.6 / 69.2 | 81.9 / 70.4 | 63.0 / 52.9 | 71.2 / 60.8 | 81.5 / 75.2 | 80.4 / 66.8 | 75.4 / 64.5 |\n| Data-augmentation mBERT      | 84.2 / 74.1 | 86.4 / 74.7 | 77.6 / 65.5 | 84.2 / 74.2 | 88.5 / 80.2 | 75.2 / 67.4 | 81.0 / 70.1 | 85.5 / 79.8 | 84.8 / 71.6 | 83.0 / 73.0 |'
